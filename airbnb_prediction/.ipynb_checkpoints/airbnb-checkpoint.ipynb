# %% [markdown]
# Uppgift: Rena data. Bygg regressionsmodell och analysera prestanda. Vi ska säga om modellen är statistiskt signifikant.
# Runt 10 variabler i ett dataset räcker att presentera, som en data-story.
# 10-15 minuters presentation då det är mer data att jobba mot.
#
# Idé: Ta ett dataset för AirBnb Stockholm, rena data och bytt regressionsmodell, förslagsvis kan vi prediktera pris per natt.
# Dataset: AirBnb (https://insideairbnb.com/)
# listings.csv	Summary information and metrics for listings in Stockholm (good for visualisations).

# %%
import pandas as pd

# Bekanta oss med datasetet!

df = pd.read_csv('airbnb_listings_stockholm_detailed.csv')
print("5 första posterna (df.head()):")
print(df.head())

print("5 slumpmässiga poster (df.sample(5)):")
print(df.sample(5))

print("Statistik på alla numeriska kolumneriska kolumner (df.describe):")
print(df.describe())          # statistik på alla numeriska kolumner

print("Hur många observationer per område (df['neighbourhood'])")
print(df['neighbourhood'].value_counts())  # hur många i varje område

print("df.info()")
print(df.info())
# Out:
# 5 första posterna (df.head()):
#        id                          listing_url       scrape_id last_scraped  \
# 0  164448  https://www.airbnb.com/rooms/164448  20250929042406   2025-09-29
# 1  220851  https://www.airbnb.com/rooms/220851  20250929042406   2025-09-29
# 2  238411  https://www.airbnb.com/rooms/238411  20250929042406   2025-09-29
# 3  242188  https://www.airbnb.com/rooms/242188  20250929042406   2025-09-29
# 4  273906  https://www.airbnb.com/rooms/273906  20250929042406   2025-09-29
#
#         source                                         name  \
# 0  city scrape  Double room in central Stockholm with Wi-Fi
# 1  city scrape                      One room in appartement
# 2  city scrape          Cozy apartment in central Stockholm
# 3  city scrape  Single room in central Stockholm with Wi-Fi
# 4  city scrape               Penthouse in central Stockholm
#
#                                          description  \
# 0  I am renting out a nice double room on the top...
# 1                                           Welcome!
# 2                                                NaN
# 3  I am renting out a nice single room on the top...
# 4                                                NaN
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Many restaurangs wery close and walkingdistanc...
# 2  Restaurants, cafés, museums, art galleries, pa...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f56d8d10-a7fa...   784312  ...
# 1  https://a0.muscache.com/pictures/2085606/7a706...   412283  ...
# 2  https://a0.muscache.com/pictures/2806060/7fc68...  1250232  ...
# 3  https://a0.muscache.com/pictures/2303148/55d1e...   784312  ...
# 4  https://a0.muscache.com/pictures/2881091/f5404...  1432722  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.97                   4.84                4.76
# 1                        4.88                   4.82                4.71
# 2                        4.95                   4.85                4.64
# 3                        4.97                   4.89                4.83
# 4                        4.75                   5.00                5.00
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              2
# 1     NaN                f                              2
# 2     NaN                f                              1
# 3     NaN                f                              2
# 4     NaN                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           1
# 2                                           1
# 3                                           0
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            2
# 1                                            1
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              2.63
# 1                                           0              0.39
# 2                                           0              0.65
# 3                                           0              2.68
# 4                                           0              0.02
#
# [5 rows x 79 columns]
# 5 slumpmässiga poster (df.sample(5)):
#                        id                                       listing_url  \
# 2569   895622863310522351   https://www.airbnb.com/rooms/895622863310522351
# 4007  1257399803990513686  https://www.airbnb.com/rooms/1257399803990513686
# 1989   648157214982908411   https://www.airbnb.com/rooms/648157214982908411
# 823              24660671             https://www.airbnb.com/rooms/24660671
# 4164  1319719649227959153  https://www.airbnb.com/rooms/1319719649227959153
#
#            scrape_id last_scraped           source  \
# 2569  20250929042406   2025-09-29  previous scrape
# 4007  20250929042406   2025-09-29      city scrape
# 1989  20250929042406   2025-09-29      city scrape
# 823   20250929042406   2025-09-29  previous scrape
# 4164  20250929042406   2025-09-29  previous scrape
#
#                                                 name  \
# 2569                 Varm och vacker plats i kransen
# 4007                              Apartment i Farsta
# 1989                                  Awesome studio
# 823   Newly built flat close to Drottningholm Caste!
# 4164                        50 kvm in Stockholm city
#
#                                             description neighborhood_overview  \
# 2569  Here is space for peace, warmth, creativity an...                   NaN
# 4007  Practical and affordable apartment in Farsta, ...                   NaN
# 1989  Newly renovated studio apartment in a historic...                   NaN
# 823   Newly build apartment close to Drottningholm c...                   NaN
# 4164       50 kvm in Stockholm city for long time rent.                   NaN
#
#                                             picture_url    host_id  ...  \
# 2569  https://a0.muscache.com/pictures/miso/Hosting-...  494442693  ...
# 4007  https://a0.muscache.com/pictures/miso/Hosting-...  590905887  ...
# 1989  https://a0.muscache.com/pictures/miso/Hosting-...   78393845  ...
# 823   https://a0.muscache.com/pictures/63f06066-a38a...   98673764  ...
# 4164  https://a0.muscache.com/pictures/hosting/Hosti...   39528931  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 2569                        4.96                   4.93                4.68
# 4007                         NaN                    NaN                 NaN
# 1989                        4.53                   4.93                4.62
# 823                         4.88                   4.63                4.88
# 4164                         NaN                    NaN                 NaN
#
#      license instant_bookable calculated_host_listings_count  \
# 2569     NaN                f                              1
# 4007     NaN                f                              1
# 1989     NaN                f                              1
# 823      NaN                f                              1
# 4164     NaN                t                              1
#
#      calculated_host_listings_count_entire_homes  \
# 2569                                           1
# 4007                                           0
# 1989                                           1
# 823                                            1
# 4164                                           1
#
#      calculated_host_listings_count_private_rooms  \
# 2569                                            0
# 4007                                            1
# 1989                                            0
# 823                                             0
# 4164                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 2569                                           0              1.00
# 4007                                           0               NaN
# 1989                                           0              7.22
# 823                                            0              0.09
# 4164                                           0               NaN
#
# [5 rows x 79 columns]
# Statistik på alla numeriska kolumneriska kolumner (df.describe):
#                  id     scrape_id       host_id  host_listings_count  \
# count  4.955000e+03  4.955000e+03  4.955000e+03          4951.000000
# mean   6.984013e+17  2.025093e+13  1.978429e+08             7.068875
# std    5.666998e+17  0.000000e+00  2.071420e+08            30.415664
# min    1.644480e+05  2.025093e+13  4.457000e+03             1.000000
# 25%    3.730808e+07  2.025093e+13  2.449362e+07             1.000000
# 50%    8.745692e+17  2.025093e+13  1.003326e+08             1.000000
# 75%    1.181723e+18  2.025093e+13  3.595140e+08             2.000000
# max    1.519717e+18  2.025093e+13  7.205346e+08          1456.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                4951.000000                           0.0  4955.000000
# mean                   12.564532                           NaN    59.318088
# std                   133.107379                           NaN     0.032222
# min                     1.000000                           NaN    59.231950
# 25%                     1.000000                           NaN    59.297375
# 50%                     2.000000                           NaN    59.317130
# 75%                     4.000000                           NaN    59.337973
# max                  8775.000000                           NaN    59.418950
#
#          longitude  accommodates    bathrooms  ...  review_scores_checkin  \
# count  4955.000000   4955.000000  3189.000000  ...            4085.000000
# mean     18.030057      3.502523     1.287551  ...               4.860891
# std       0.065606      2.023216     1.091029  ...               0.297532
# min      17.773110      1.000000     0.000000  ...               1.000000
# 25%      17.999478      2.000000     1.000000  ...               4.840000
# 50%      18.046900      3.000000     1.000000  ...               4.950000
# 75%      18.076503      4.000000     1.500000  ...               5.000000
# max      18.191930     16.000000    50.000000  ...               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                  4085.000000             4085.000000
# mean                      4.869435                4.810487
# std                       0.308329                0.311399
# min                       1.000000                1.000000
# 25%                       4.860000                4.750000
# 50%                       4.980000                4.900000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  license  calculated_host_listings_count  \
# count          4085.000000      0.0                     4955.000000
# mean              4.719907      NaN                        4.620182
# std               0.366157      NaN                        9.952706
# min               1.000000      NaN                        1.000000
# 25%               4.640000      NaN                        1.000000
# 50%               4.800000      NaN                        1.000000
# 75%               4.950000      NaN                        2.000000
# max               5.000000      NaN                       51.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  4955.000000
# mean                                      4.040565
# std                                       9.927359
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                      51.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   4955.000000
# mean                                       0.530575
# std                                        1.945364
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       21.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  4955.000000        4086.000000
# mean                                      0.042987           1.280049
# std                                       0.428554           2.162293
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.180000
# 50%                                       0.000000           0.500000
# 75%                                       0.000000           1.540000
# max                                       6.000000          52.340000
#
# [8 rows x 45 columns]
# Hur många observationer per område (df['neighbourhood'])
# neighbourhood
# Stockholm, Stockholms län, Sweden                375
# Södermalm, Stockholms län, Sweden                352
# Kungsholmen, Stockholms län, Sweden              142
# Hägersten-Liljeholmen, Stockholms län, Sweden    118
# Stockholm, Stockholm County, Sweden               95
#                                                 ...
# Segeltorp, Stockholms län, Sweden                  1
# Stockholm, Södermanlands län, Sweden               1
# Trångsund, Stockholms län, Sweden                  1
# Stockholm, Hässelby,  Stockholm, Sweden            1
# Stockholms, Stockholms län, Sweden                 1
# Name: count, Length: 72, dtype: int64
# df.info()
# <class 'pandas.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4955 non-null   int64
#  1   listing_url                                   4955 non-null   str
#  2   scrape_id                                     4955 non-null   int64
#  3   last_scraped                                  4955 non-null   str
#  4   source                                        4955 non-null   str
#  5   name                                          4955 non-null   str
#  6   description                                   4763 non-null   str
#  7   neighborhood_overview                         1780 non-null   str
#  8   picture_url                                   4955 non-null   str
#  9   host_id                                       4955 non-null   int64
#  10  host_url                                      4955 non-null   str
#  11  host_name                                     4951 non-null   str
#  12  host_since                                    4951 non-null   str
#  13  host_location                                 4015 non-null   str
#  14  host_about                                    2242 non-null   str
#  15  host_response_time                            3379 non-null   str
#  16  host_response_rate                            3379 non-null   str
#  17  host_acceptance_rate                          3801 non-null   str
#  18  host_is_superhost                             4927 non-null   str
#  19  host_thumbnail_url                            4951 non-null   str
#  20  host_picture_url                              4951 non-null   str
#  21  host_neighbourhood                            1370 non-null   str
#  22  host_listings_count                           4951 non-null   float64
#  23  host_total_listings_count                     4951 non-null   float64
#  24  host_verifications                            4951 non-null   str
#  25  host_has_profile_pic                          4951 non-null   str
#  26  host_identity_verified                        4951 non-null   str
#  27  neighbourhood                                 1780 non-null   str
#  28  neighbourhood_cleansed                        4955 non-null   str
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      4955 non-null   float64
#  31  longitude                                     4955 non-null   float64
#  32  property_type                                 4955 non-null   str
#  33  room_type                                     4955 non-null   str
#  34  accommodates                                  4955 non-null   int64
#  35  bathrooms                                     3189 non-null   float64
#  36  bathrooms_text                                4947 non-null   str
#  37  bedrooms                                      4697 non-null   float64
#  38  beds                                          3188 non-null   float64
#  39  amenities                                     4955 non-null   str
#  40  price                                         3190 non-null   str
#  41  minimum_nights                                4955 non-null   int64
#  42  maximum_nights                                4955 non-null   int64
#  43  minimum_minimum_nights                        4952 non-null   float64
#  44  maximum_minimum_nights                        4952 non-null   float64
#  45  minimum_maximum_nights                        4952 non-null   float64
#  46  maximum_maximum_nights                        4952 non-null   float64
#  47  minimum_nights_avg_ntm                        4955 non-null   float64
#  48  maximum_nights_avg_ntm                        4955 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              4771 non-null   str
#  51  availability_30                               4955 non-null   int64
#  52  availability_60                               4955 non-null   int64
#  53  availability_90                               4955 non-null   int64
#  54  availability_365                              4955 non-null   int64
#  55  calendar_last_scraped                         4955 non-null   str
#  56  number_of_reviews                             4955 non-null   int64
#  57  number_of_reviews_ltm                         4955 non-null   int64
#  58  number_of_reviews_l30d                        4955 non-null   int64
#  59  availability_eoy                              4955 non-null   int64
#  60  number_of_reviews_ly                          4955 non-null   int64
#  61  estimated_occupancy_l365d                     4955 non-null   int64
#  62  estimated_revenue_l365d                       3190 non-null   float64
#  63  first_review                                  4086 non-null   str
#  64  last_review                                   4086 non-null   str
#  65  review_scores_rating                          4086 non-null   float64
#  66  review_scores_accuracy                        4086 non-null   float64
#  67  review_scores_cleanliness                     4086 non-null   float64
#  68  review_scores_checkin                         4085 non-null   float64
#  69  review_scores_communication                   4085 non-null   float64
#  70  review_scores_location                        4085 non-null   float64
#  71  review_scores_value                           4085 non-null   float64
#  72  license                                       0 non-null      float64
#  73  instant_bookable                              4955 non-null   str
#  74  calculated_host_listings_count                4955 non-null   int64
#  75  calculated_host_listings_count_entire_homes   4955 non-null   int64
#  76  calculated_host_listings_count_private_rooms  4955 non-null   int64
#  77  calculated_host_listings_count_shared_rooms   4955 non-null   int64
#  78  reviews_per_month                             4086 non-null   float64
# dtypes: float64(25), int64(20), str(34)
# memory usage: 3.0 MB
# None
