# %% [markdown]
# # Prisprediktion för Airbnb Stockholm med Neurala Nätverk
#
# **Deep Learning-grupparbete — TensorFlow**
#
# Vi revisitar vårt Airbnb-dataset för Stockholm och undersöker vad vi kan åstadkomma med neurala nätverk. Den centrala frågan: **hur mycket av en bostads pris kan förklaras av hyresvärdens egna fritext-beskrivningar — och hur mycket tillför strukturerad data (antal rum, läge, recensioner)?**
#
# Vi bygger två pipelines:
#
# 1. **Pipeline 1 — Bara text:** TF-IDF på fem fritextfält → Sequential-nätverk
# 2. **Pipeline 2 — Allt:** text + numeriska + kategoriska features
#
# Båda utvärderas med MAE, RMSE, R² och MAPE, och vi analyserar vilka features som driver priset med permutation importance. Avslutningsvis optimerar vi med Keras Tuner Grid Search och bygger en interaktiv prisestimator.

# %% [markdown]
# ## 1. Utforskande dataanalys (EDA)
#
# Innan vi bygger modeller utforskar vi datasetet: prisfördelning, relationer mellan variabler, och hur priset varierar med läge och bostadstyp. Detta motiverar våra senare val av features och förbehandling.

# %%
# ============================================================
# EDA — UTFORSKANDE DATAANALYS
# Beskriver datasetet och relationer mellan variabler
# Körs på rådata innan modellering
# ============================================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Ladda om rådata för EDA (oberoende av modell-pipelines)
df_eda = pd.read_csv("data/airbnb_listings_stockholm_detailed.csv")
#df_eda.to_excel('output_raw.xlsx')

# Rensa pris (samma logik som i pipelines)
df_eda["price"] = (
    df_eda["price"].astype(str)
                   .str.replace(r"[\$,]", "", regex=True)
                   .str.strip()
                   .replace("", np.nan)
                   .astype(float)
)
df_eda = df_eda.dropna(subset=["price"])

print(f"Antal listings: {len(df_eda):,}")
print(f"Antal kolumner: {df_eda.shape[1]}")
print(f"Pris-range:     {df_eda['price'].min():.0f} - {df_eda['price'].max():.0f} SEK")
print(f"Medelpris:      {df_eda['price'].mean():.0f} SEK")
print(f"Median:         {df_eda['price'].median():.0f} SEK")
# Out:
# Antal listings: 3,190
# Antal kolumner: 79
# Pris-range:     120 - 112218 SEK
# Medelpris:      1690 SEK
# Median:         1200 SEK

# %%
#df_eda.to_excel('output.xlsx')
# Efter rensnng av objekt som saknar prisinfo så återstår 3190 observationer, 
# vilket kan anses lågt för att neurala nätverk ska prestera som bäst.

# %% [markdown]
# ### 1.1 Prisfördelning
#
# Airbnb-priser är typiskt **höger-skeva** — många billiga bostäder och ett fåtal mycket dyra. Det syns tydligt nedan. Vi stryker de översta 5 % (priser över 95:e percentilen) eftersom extrema lyxobjekt annars destabiliserar träningen och drar upp felen oproportionerligt.

# %%
# --- Pris-fördelning: hela datan vs den vi tränar på ---
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

axes[0].hist(df_eda["price"], bins=80, edgecolor="black", color="#4C72B0", alpha=0.8)
axes[0].set_xlabel("Pris (SEK)")
axes[0].set_ylabel("Antal listings")
axes[0].set_title("Hela pris-fördelningen (med outliers)")
axes[0].axvline(df_eda["price"].median(), color="red", linestyle="--",
                label=f"Median: {df_eda['price'].median():.0f} SEK")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

limit = df_eda["price"].quantile(0.95)
filtered = df_eda[(df_eda["price"] >= 10) & (df_eda["price"] <= limit)]
axes[1].hist(filtered["price"], bins=60, edgecolor="black", color="#55A868", alpha=0.8)
axes[1].set_xlabel("Pris (SEK)")
axes[1].set_ylabel("Antal listings")
axes[1].set_title(f"Anvand data (10 - {limit:.0f} SEK, 95:e percentil)")
axes[1].axvline(filtered["price"].median(), color="red", linestyle="--",
                label=f"Median: {filtered['price'].median():.0f} SEK")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Priserna ar HOGER-SKEVA: manga billiga, fa mycket dyra.")
print(f"95:e percentilen: {limit:.0f} SEK - vi strok allt ovanfor for stabilare traning.")
# Out:
# Priserna ar HOGER-SKEVA: manga billiga, fa mycket dyra.
# 95:e percentilen: 3907 SEK - vi strok allt ovanfor for stabilare traning.

# %% [markdown]
# ### 1.2 Korrelationer mellan numeriska variabler
#
# Korrelationsmatrisen visar hur de numeriska variablerna hänger ihop med varandra och med priset. Vi förväntar oss att storleksmått (`accommodates`, `bedrooms`, `beds`) korrelerar starkast med pris, eftersom större bostäder kostar mer.

# %%
# --- Korrelationsmatris: numeriska features ---
num_features = [
    "price", "accommodates", "bedrooms", "bathrooms", "beds",
    "minimum_nights", "number_of_reviews", "reviews_per_month",
    "review_scores_rating", "availability_365",
    "latitude", "longitude",
]

corr = df_eda[num_features].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="RdBu_r", center=0,
            cbar_kws={"shrink": 0.8}, square=True, linewidths=0.5)
plt.title("Korrelationsmatris - numeriska features", pad=15)
plt.tight_layout()
plt.show()

# Korrelationer med pris
price_corr = corr["price"].drop("price").sort_values(ascending=False)
print("Korrelationer med pris:")
for feat, val in price_corr.items():
    direction = "upp" if val > 0 else "ner"
    print(f"  {feat:30s}: {val:>+.3f} ({direction})")
# Out:
# Korrelationer med pris:
#   accommodates                  : +0.161 (upp)
#   bedrooms                      : +0.128 (upp)
#   beds                          : +0.103 (upp)
#   bathrooms                     : +0.045 (upp)
#   review_scores_rating          : +0.042 (upp)
#   longitude                     : +0.034 (upp)
#   latitude                      : +0.021 (upp)
#   availability_365              : +0.009 (upp)
#   minimum_nights                : -0.034 (ner)
#   number_of_reviews             : -0.039 (ner)
#   reviews_per_month             : -0.054 (ner)

# %% [markdown]
# ### 1.3 Pris per rums- och bostadstyp
#
# Kategoriska variabler bär mycket prisinformation. En hel lägenhet (`Entire home/apt`) kostar typiskt 2–3 gånger mer än ett privat rum, oavsett storlek. Detta motiverar att vi inkluderar `room_type` och `property_type` som features i Pipeline 2.

# %%
# --- Pris per rumstyp och bostadstyp ---
plot_df = df_eda[df_eda["price"] <= df_eda["price"].quantile(0.95)].copy()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

room_order = plot_df.groupby("room_type")["price"].median().sort_values().index
sns.boxplot(data=plot_df, x="room_type", y="price", order=room_order, ax=axes[0],
            palette="Blues_r")
axes[0].set_title("Pris per rumstyp")
axes[0].set_xlabel("Rumstyp"); axes[0].set_ylabel("Pris (SEK)")
axes[0].tick_params(axis="x", rotation=20)
axes[0].grid(True, alpha=0.3, axis="y")

top_props = plot_df["property_type"].value_counts().head(6).index
prop_df = plot_df[plot_df["property_type"].isin(top_props)]
prop_order = prop_df.groupby("property_type")["price"].median().sort_values().index
sns.boxplot(data=prop_df, x="property_type", y="price", order=prop_order, ax=axes[1],
            palette="Greens_r")
axes[1].set_title("Pris per bostadstyp (topp 6)")
axes[1].set_xlabel("Bostadstyp"); axes[1].set_ylabel("Pris (SEK)")
axes[1].tick_params(axis="x", rotation=30)
axes[1].grid(True, alpha=0.3, axis="y")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ES7233\AppData\Local\Temp\ipykernel_19464\1818999109.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=plot_df, x="room_type", y="price", order=room_order, ax=axes[0],
# C:\Users\ES7233\AppData\Local\Temp\ipykernel_19464\1818999109.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=prop_df, x="property_type", y="price", order=prop_order, ax=axes[1],

# %% [markdown]
# ### 1.4 Pris per stadsdel
#
# Läget är en av de starkaste prisdrivarna. Innerstadsområden som Norrmalm och Östermalm har betydligt högre medianpris än ytterstaden. Notera den stora spridningen *inom* varje stadsdel — läget ensamt förklarar inte allt.

# %%
# --- Pris per stadsdel (topp 15 efter antal listings) ---
top_neighborhoods = df_eda["neighbourhood_cleansed"].value_counts().head(15).index
neigh_df = plot_df[plot_df["neighbourhood_cleansed"].isin(top_neighborhoods)]
neigh_order = neigh_df.groupby("neighbourhood_cleansed")["price"].median().sort_values().index

plt.figure(figsize=(12, 6))
sns.boxplot(data=neigh_df, y="neighbourhood_cleansed", x="price",
            order=neigh_order, palette="viridis")
plt.title("Pris per stadsdel - topp 15 (sorterat efter medianpris)")
plt.xlabel("Pris (SEK)"); plt.ylabel("Stadsdel")
plt.grid(True, alpha=0.3, axis="x")
plt.tight_layout()
plt.show()

medians = neigh_df.groupby("neighbourhood_cleansed")["price"].median().sort_values()
print("5 billigaste stadsdelar (median):")
for n, p in medians.head().items():
    print(f"  {n:30s}: {p:>5.0f} SEK")
print("\n5 dyraste stadsdelar (median):")
for n, p in medians.tail().items():
    print(f"  {n:30s}: {p:>5.0f} SEK")
# Out:
# C:\Users\ES7233\AppData\Local\Temp\ipykernel_19464\1809170420.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=neigh_df, y="neighbourhood_cleansed", x="price",
# 5 billigaste stadsdelar (median):
#   Rinkeby-Tensta                :   588 SEK
#   Spånga-Tensta                 :   593 SEK
#   Skärholmens                   :   646 SEK
#   Enskede-Årsta-Vantörs         :   810 SEK
#   Hässelby-Vällingby            :   837 SEK
#
# 5 dyraste stadsdelar (median):
#   Bromma                        :  1231 SEK
#   Östermalms                    :  1302 SEK
#   Norrmalms                     :  1367 SEK
#   Södermalms                    :  1384 SEK
#   Farsta                        :  1404 SEK

# %% [markdown]
# ### 1.5 Geografisk spridning
#
# När vi färglägger varje listing efter pris ser vi tydligt att de dyra bostäderna klustrar i innerstaden. Det är därför `latitude` och `longitude` blir så prediktiva i modellen — koordinaterna kodar implicit närheten till centrum.

# %%
# --- Geografisk spridning: var ar det dyrt? ---
plt.figure(figsize=(10, 9))
scatter = plt.scatter(
    plot_df["longitude"], plot_df["latitude"],
    c=plot_df["price"], cmap="YlOrRd",
    s=12, alpha=0.6, edgecolors="none")
plt.colorbar(scatter, label="Pris (SEK)")
plt.xlabel("Longitud"); plt.ylabel("Latitud")
plt.title("Geografisk fordelning av listings - farg = pris")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Dyrare listings (morkrott) klustrar i innerstan.")
print("Darfor ar 'longitude' en av modellens viktigaste features.")
# Out:
# Dyrare listings (morkrott) klustrar i innerstan.
# Darfor ar 'longitude' en av modellens viktigaste features.

# %% [markdown]
# ### 1.6 Recensioner och kapacitet
#
# Antal recensioner säger mer om popularitet än om pris (svag korrelation), medan kapacitet (`accommodates`) har ett tydligt positivt samband med pris.

# %%
# --- Recensioner och kapacitet vs pris ---
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].scatter(plot_df["number_of_reviews"], plot_df["price"],
                alpha=0.3, s=15, color="#4C72B0")
axes[0].set_xlabel("Antal recensioner"); axes[0].set_ylabel("Pris (SEK)")
axes[0].set_title("Antal recensioner vs pris")
axes[0].grid(True, alpha=0.3)

acc_df = plot_df[plot_df["accommodates"].between(1, 10)]
sns.boxplot(data=acc_df, x="accommodates", y="price", ax=axes[1], palette="Oranges")
axes[1].set_xlabel("Antal personer (accommodates)"); axes[1].set_ylabel("Pris (SEK)")
axes[1].set_title("Pris per kapacitet")
axes[1].grid(True, alpha=0.3, axis="y")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ES7233\AppData\Local\Temp\ipykernel_19464\3238444538.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=acc_df, x="accommodates", y="price", ax=axes[1], palette="Oranges")

# %% [markdown]
# ### EDA — sammanfattning
#
# - **Prisfördelningen är höger-skev** → vi stryker top 5 % för stabilare träning.
# - **Storlek + läge är fundamentet** → `accommodates`, `bedrooms` och koordinater korrelerar starkast med pris.
# - **Kategoriska variabler bär mycket signal** → `room_type` och stadsdel ger stora prisskillnader.
# - **Ingen enskild variabel dominerar** → detta är ett multi-faktor-problem, vilket motiverar en modell som kan väga samman många features.
#
# Med denna förståelse bygger vi nu våra två pipelines.

# %% [markdown]
# ## 2. Pipeline 1 — Endast textvariabler
#
# Vår första fråga: **hur långt kommer vi med enbart hyresvärdarnas fritext?** Vi använder fem textfält — `name`, `description`, `amenities`, `neighborhood_overview` och `host_about` — och omvandlar dem till numeriska features med **TF-IDF** (Term Frequency–Inverse Document Frequency). TF-IDF räknar hur ofta varje ord förekommer, viktat efter hur unikt ordet är.
#
# Resultatet matas in i ett **Sequential-nätverk** av samma typ som vi använde för Iris-datasetet i kursen: täta lager (`Dense`) med ReLU-aktivering och `Dropout` för regularisering. Output är en enda neuron med linjär aktivering, eftersom vi förutsäger ett kontinuerligt pris (regression).

# %%
# Vi vill veta vad vi kan göra för analys baserat på text-variablerna (ostrukturerade datan) i datasetet, i synnerhet description.

# %%
# ============================================================
# PIPELINE 1: BARA TEXT
# Förbehandling: TF-IDF på 5 textfält
# Modell: Sequential
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# ============================================================
# STEG 1: Ladda data
# ============================================================
df = pd.read_csv("data/airbnb_listings_stockholm_detailed.csv")
print(f"Ursprunglig storlek: {len(df)} rader")

target = "price"
text_cols = ["name", "description", "amenities",
             "neighborhood_overview", "host_about"]

# ============================================================
# STEG 2: Rensa pris
# ============================================================
df[target] = (
    df[target].astype(str)
              .str.replace(r"[\$,]", "", regex=True)
              .str.strip()
              .replace("", np.nan)
              .astype(float)
)
df = df.dropna(subset=[target])

# ============================================================
# STEG 3: Rensa textfält (NaN → "okänt", ta bort unicode)
# ============================================================
for c in text_cols:
    df[c] = (
        df[c]
        .fillna("okänt")
        .astype(str)
        .str.strip()
        .apply(lambda s: s.encode("latin-1", errors="ignore").decode("latin-1"))
        .replace("", "okänt")
        .replace("nan", "okänt")
    )

# ============================================================
# STEG 4: Stryp pris-outliers
# ============================================================
df = df[(df[target] >= 10) & (df[target] <= df[target].quantile(0.95))]

print(f"Efter rensning: {len(df)} rader kvar")
print(f"Pris: {df[target].min():.0f} → {df[target].max():.0f} SEK (medel {df[target].mean():.0f})")

# ============================================================
# STEG 5: Train/test split
# ============================================================
y = df[target].values.astype("float32")

X_train_df, X_test_df, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42)

print(f"Train: {len(X_train_df)}, Test: {len(X_test_df)}")

# ============================================================
# STEG 6: TF-IDF på varje textfält
# ============================================================
print("\nBygger TF-IDF-vektorer...")

tfidf_settings = {
    "name":                  100,
    "description":           200,
    "amenities":             100,
    "neighborhood_overview": 50,
    "host_about":            50,
}

tfidf_vectorizers = {}
tfidf_train = []
tfidf_test = []

for col, max_feat in tfidf_settings.items():
    tfidf = TfidfVectorizer(
        max_features=max_feat,
        stop_words="english",
        lowercase=True,
        min_df=5,
        ngram_range=(1, 1))
    
    train_vec = tfidf.fit_transform(X_train_df[col].values)
    test_vec  = tfidf.transform(X_test_df[col].values)
    
    tfidf_vectorizers[col] = tfidf
    tfidf_train.append(train_vec)
    tfidf_test.append(test_vec)
    print(f"  {col:25s}: {train_vec.shape[1]:>3} features (max {max_feat})")

# ============================================================
# STEG 7: Kombinera alla TF-IDF-matriser
# ============================================================
X_train_text = hstack(tfidf_train).toarray().astype("float32")
X_test_text  = hstack(tfidf_test).toarray().astype("float32")

print(f"\nFinal feature matrix:")
print(f"  Train: {X_train_text.shape}")
print(f"  Test:  {X_test_text.shape}")
print(f"  Totalt {X_train_text.shape[1]} features (bara text)")

# ============================================================
# STEG 8: Bygg Sequential modell
# ============================================================
model_text = tf.keras.models.Sequential([
    tf.keras.Input(shape=(X_train_text.shape[1],)),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(1)              # regression: 1 neuron, linjär
])

model_text.compile(
    optimizer="adam",
    loss="mae",
    metrics=["mae"])

print(f"\nModell — antal parametrar: {model_text.count_params():,}")

# ============================================================
# STEG 9: Träna med EarlyStopping
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True)

history_text = model_text.fit(
    X_train_text, y_train,
    validation_data=(X_test_text, y_test),
    epochs=100, batch_size=32,
    callbacks=[early_stop],
    verbose=1)

# ============================================================
# STEG 10: Utvärdera
# ============================================================
y_pred_text = model_text.predict(X_test_text).flatten()
mae_text = np.mean(np.abs(y_pred_text - y_test))
rmse_text = np.sqrt(np.mean((y_pred_text - y_test) ** 2))

mean_pred = y_train.mean()
mae_base = np.mean(np.abs(y_test - mean_pred))

mape  = np.mean(np.abs((y_test - y_pred_text) / y_test)) * 100
r2    = r2_score(y_test, y_pred_text)
medae = np.median(np.abs(y_test - y_pred_text))


print("\n" + "=" * 50)
print("PIPELINE 1 — ENBART TEXT")
print("=" * 50)
print(f"Antal features:        {X_train_text.shape[1]}")
print(f"MAE 'gissa medel':     {mae_base:.1f} SEK")
print(f"MAE pipeline 1 (text): {mae_text:.1f} SEK")
print(f"RMSE:                  {rmse_text:.1f} SEK")
print(f"Relativt fel:          {mae_text/y_test.mean()*100:.1f}%")
print(f"Median AE: {medae:>7.1f} SEK   (typiskt fel — robust)")
print(f"MAPE:      {mape:>7.1f} %     (procentuellt fel)")
print(f"R²:        {r2:>7.3f}         (förklarad variation)")

# ============================================================
# STEG 11: Plotta loss-kurvan
# ============================================================
plt.figure(figsize=(10, 4))
plt.plot(history_text.history["loss"], label="Training loss")
plt.plot(history_text.history["val_loss"], label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("MAE (SEK)")
plt.title("Pipeline 1: Loss över epochs (bara text)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Ursprunglig storlek: 4955 rader
# Efter rensning: 3030 rader kvar
# Pris: 120 → 3905 SEK (medel 1362)
# Train: 2424, Test: 606
#
# Bygger TF-IDF-vektorer...
#   name                     : 100 features (max 100)
#   description              : 200 features (max 200)
#   amenities                : 100 features (max 100)
#   neighborhood_overview    :  50 features (max 50)
#   host_about               :  50 features (max 50)
#
# Final feature matrix:
#   Train: (2424, 500)
#   Test:  (606, 500)
#   Totalt 500 features (bara text)
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
#
# Modell — antal parametrar: 74,497
# Epoch 1/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1305.6385 - mae: 1305.6385 - val_loss: 972.6491 - val_mae: 972.6491
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 687.4240 - mae: 687.4240 - val_loss: 607.9233 - val_mae: 607.9233
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 606.2758 - mae: 606.2758 - val_loss: 572.8009 - val_mae: 572.8009
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 573.7188 - mae: 573.7188 - val_loss: 537.3209 - val_mae: 537.3209
# Epoch 5/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 536.5244 - mae: 536.5244 - val_loss: 504.7217 - val_mae: 504.7217
# Epoch 6/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 507.0558 - mae: 507.0558 - val_loss: 476.2138 - val_mae: 476.2138
# Epoch 7/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 484.6274 - mae: 484.6274 - val_loss: 460.1306 - val_mae: 460.1306
# Epoch 8/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 465.7070 - mae: 465.7070 - val_loss: 453.3638 - val_mae: 453.3638
# Epoch 9/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 450.8975 - mae: 450.8975 - val_loss: 450.0476 - val_mae: 450.0476
# Epoch 10/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 452.3908 - mae: 452.3908 - val_loss: 446.1533 - val_mae: 446.1533
# Epoch 11/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 433.5082 - mae: 433.5082 - val_loss: 445.2807 - val_mae: 445.2807
# Epoch 12/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 441.5532 - mae: 441.5532 - val_loss: 443.4572 - val_mae: 443.4572
# Epoch 13/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 438.1097 - mae: 438.1097 - val_loss: 443.4062 - val_mae: 443.4062
# Epoch 14/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 429.9790 - mae: 429.9790 - val_loss: 442.0221 - val_mae: 442.0221
# Epoch 15/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 425.9365 - mae: 425.9365 - val_loss: 442.7939 - val_mae: 442.7939
# Epoch 16/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 428.3300 - mae: 428.3300 - val_loss: 443.2589 - val_mae: 443.2589
# Epoch 17/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 421.4615 - mae: 421.4615 - val_loss: 444.1950 - val_mae: 444.1950
# Epoch 18/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 417.3740 - mae: 417.3740 - val_loss: 444.2268 - val_mae: 444.2268
# Epoch 19/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 420.9431 - mae: 420.9431 - val_loss: 443.8966 - val_mae: 443.8966
# Epoch 20/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 413.0549 - mae: 413.0549 - val_loss: 444.1219 - val_mae: 444.1219
# Epoch 21/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 409.1689 - mae: 409.1689 - val_loss: 445.8101 - val_mae: 445.8101
# Epoch 22/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 404.7217 - mae: 404.7217 - val_loss: 446.1322 - val_mae: 446.1322
# Epoch 23/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 405.5798 - mae: 405.5798 - val_loss: 444.8086 - val_mae: 444.8086
# Epoch 24/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 405.5575 - mae: 405.5575 - val_loss: 447.3065 - val_mae: 447.3065
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# ==================================================
# PIPELINE 1 — ENBART TEXT
# ==================================================
# Antal features:        500
# MAE 'gissa medel':     672.7 SEK
# MAE pipeline 1 (text): 442.0 SEK
# RMSE:                  611.7 SEK
# Relativt fel:          33.2%
# Median AE:   317.8 SEK   (typiskt fel — robust)
# MAPE:         42.9 %     (procentuellt fel)
# R²:          0.441         (förklarad variation)

# %% [markdown]
# ### 2.1 Analys av träningskurvan
#
# Loss-kurvan berättar om modellen lär sig sunt eller överanpassar. Vi vill se att tränings- och valideringsförlust sjunker tillsammans och planar ut — utan att valideringsförlusten börjar stiga (vilket vore overfitting).

# %%
"""
Analys av loss-kurvan

Båda kurvor dyker brant under första epochs — modellen lär sig snabbt grunderna
Båda planar ut runt epoch 10 — modellen har hittat sin nivå
Validation loss (~445) ligger lätt över training loss (~400) — en hälsosam liten skillnad
Ingen overfitting — validation loss går inte upp, bara stannar
EarlyStopping slog till runt epoch 22 (patience=10 från bästa val_loss runt epoch 12)

Det här är en välbeteende modell — visar att du satt regulariseringen (dropout) lagom.
"""
# Out:
# '\nAnalys av loss-kurvan\nBilden visar en lärobokstypisk träningskurva:\n\nBåda kurvor dyker brant under första epochs — modellen lär sig snabbt grunderna\nBåda planar ut runt epoch 10 — modellen har hittat sin nivå\nValidation loss (~445) ligger lätt över training loss (~400) — en hälsosam liten skillnad\nIngen overfitting — validation loss går inte upp, bara stannar\nEarlyStopping slog till runt epoch 22 (patience=10 från bästa val_loss runt epoch 12)\n\nDet här är en välbeteende modell — visar att du satt regulariseringen (dropout) lagom.\n'

# %% [markdown]
# ### 2.2 Optimering med Keras Tuner Grid Search
#
# Kan vi förbättra Pipeline 1 genom att systematiskt söka efter bästa hyperparametrar? Vi använder **Keras Tuner GridSearch** för att testa olika antal neuroner, dropout-nivåer och learning rates. **Early Stopping** avbryter dåliga försök tidigt. Sökrymden är reducerad till de mest lovande kombinationerna för att hålla körtiden rimlig.

# %%
# Kan vi förbättra resultatet med Grid search och early stop?

# ============================================================
# KERAS TUNER GRID SEARCH — Pipeline 1 (bara text)
# ============================================================

import keras_tuner as kt
import tensorflow as tf
import numpy as np
from sklearn.metrics import r2_score

# ============================================================
# STEG 1: Definiera build_model med hyperparametrar
# ============================================================
def build_model(hp):
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(X_train_text.shape[1],)),
        
        # Första dolda lagret
        tf.keras.layers.Dense(
            units=hp.Choice("n_neurons_layer1", [128, 256]),
            activation="relu"
        ),
        tf.keras.layers.Dropout(
            hp.Choice("dropout_layer1", [0.3, 0.4])
        ),
        
        # Andra dolda lagret
        tf.keras.layers.Dense(
            units=hp.Choice("n_neurons_layer2", [64, 128]),
            activation="relu"
        ),
        tf.keras.layers.Dropout(
            hp.Choice("dropout_layer2", [0.2, 0.3])
        ),
        
        # Tredje dolda lagret (mindre)
        tf.keras.layers.Dense(
            units=hp.Choice("n_neurons_layer3", [32, 64]),
            activation="relu"
        ),
        
        # Output: 1 neuron, linjär (regression)
        tf.keras.layers.Dense(1)
    ])
    
    # Optimerare med olika learning rates
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005])
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    
    model.compile(
        optimizer=optimizer,
        loss="mae",
        metrics=["mae"]
    )
    return model


# ============================================================
# STEG 2: Skapa GridSearch Tuner
# ============================================================
tuner = kt.GridSearch(
    hypermodel=build_model,
    objective="val_mae",
    executions_per_trial=1,
    overwrite=True,
    directory="keras_tuner_airbnb",
    project_name="grid_search_pipeline1"
)

# Visa sökrymden
tuner.search_space_summary()


# ============================================================
# STEG 3: Kör grid search med Early Stopping
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True
)

print("\nStartar Grid Search... (tar några minuter)")
print("Early Stopping aktiverat - dåliga försök avbryts tidigt\n")

tuner.search(
    X_train_text, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)


# ============================================================
# STEG 4: Visa bästa hyperparametrar
# ============================================================
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print("\n" + "=" * 60)
print("BÄSTA HYPERPARAMETRAR FUNNA")
print("=" * 60)
print(f"  Neuroner lager 1:        {best_hps.get('n_neurons_layer1')}")
print(f"  Dropout lager 1:         {best_hps.get('dropout_layer1')}")
print(f"  Neuroner lager 2:        {best_hps.get('n_neurons_layer2')}")
print(f"  Dropout lager 2:         {best_hps.get('dropout_layer2')}")
print(f"  Neuroner lager 3:        {best_hps.get('n_neurons_layer3')}")
print(f"  Learning rate:           {best_hps.get('learning_rate')}")


# ============================================================
# STEG 5: Bygg bästa modellen och träna ordentligt
# ============================================================
best_model_text = build_model(best_hps)

print(f"\nBästa modell — antal parametrar: {best_model_text.count_params():,}")

# Mer generös Early Stopping för slutträning
early_stop_final = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=15, restore_best_weights=True
)

print("\nTränar bästa modellen i upp till 100 epochs...")
history_best_text = best_model_text.fit(
    X_train_text, y_train,
    validation_data=(X_test_text, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop_final],
    verbose=1
)


# ============================================================
# STEG 6: Utvärdera med alla mätvärden
# ============================================================
y_pred_best_text = best_model_text.predict(X_test_text).flatten()

mae   = np.mean(np.abs(y_pred_best_text - y_test))
rmse  = np.sqrt(np.mean((y_pred_best_text - y_test) ** 2))
medae = np.median(np.abs(y_test - y_pred_best_text))
mape  = np.mean(np.abs((y_test - y_pred_best_text) / y_test)) * 100
r2    = r2_score(y_test, y_pred_best_text)

print("\n" + "=" * 60)
print("PIPELINE 1 — GRID SEARCH OPTIMERAD")
print("=" * 60)
print(f"Jämförelse:")
print(f"  Original Pipeline 1:   MAE 441.7 SEK, R² 0.447")
print(f"  Grid Search Pipeline 1: MAE {mae:.1f} SEK, R² {r2:.3f}")
print(f"")
print(f"Detaljerat:")
print(f"  MAE:       {mae:>7.1f} SEK")
print(f"  Median AE: {medae:>7.1f} SEK")
print(f"  RMSE:      {rmse:>7.1f} SEK")
print(f"  MAPE:      {mape:>7.1f} %")
print(f"  R²:        {r2:>7.3f}")


# ============================================================
# STEG 7: Plotta loss-kurvan
# ============================================================
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
plt.plot(history_best_text.history["loss"], label="Training loss")
plt.plot(history_best_text.history["val_loss"], label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("MAE (SEK)")
plt.title("Pipeline 1 (Grid Search): Loss över epochs")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Trial 64 Complete [00h 00m 09s]
# val_mae: 460.3213806152344
#
# Best val_mae So Far: 457.2308349609375
# Total elapsed time: 00h 08m 14s
#
# ============================================================
# BÄSTA HYPERPARAMETRAR FUNNA
# ============================================================
#   Neuroner lager 1:        128
#   Dropout lager 1:         0.4
#   Neuroner lager 2:        128
#   Dropout lager 2:         0.2
#   Neuroner lager 3:        64
#   Learning rate:           0.001
#
# Bästa modell — antal parametrar: 88,961
#
# Tränar bästa modellen i upp till 100 epochs...
# Epoch 1/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1206.9778 - mae: 1206.9778 - val_loss: 639.5211 - val_mae: 639.5211
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 628.8252 - mae: 628.8252 - val_loss: 591.2919 - val_mae: 591.2919
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 578.5335 - mae: 578.5335 - val_loss: 552.0596 - val_mae: 552.0596
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 534.6325 - mae: 534.6325 - val_loss: 505.9807 - val_mae: 505.9807
# Epoch 5/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 494.8923 - mae: 494.8923 - val_loss: 470.0872 - val_mae: 470.0872
# Epoch 6/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 471.0549 - mae: 471.0549 - val_loss: 456.8778 - val_mae: 456.8778
# Epoch 7/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 449.1271 - mae: 449.1271 - val_loss: 449.7944 - val_mae: 449.7944
# Epoch 8/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 437.8603 - mae: 437.8603 - val_loss: 444.6648 - val_mae: 444.6648
# Epoch 9/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 431.3202 - mae: 431.3202 - val_loss: 443.7978 - val_mae: 443.7978
# Epoch 10/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 427.5292 - mae: 427.5292 - val_loss: 444.0680 - val_mae: 444.0680
# Epoch 11/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 420.7705 - mae: 420.7705 - val_loss: 442.2045 - val_mae: 442.2045
# Epoch 12/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 415.2054 - mae: 415.2054 - val_loss: 440.2042 - val_mae: 440.2042
# Epoch 13/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 409.5705 - mae: 409.5705 - val_loss: 442.7618 - val_mae: 442.7618
# Epoch 14/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 410.4590 - mae: 410.4590 - val_loss: 440.6274 - val_mae: 440.6274
# Epoch 15/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 404.4352 - mae: 404.4352 - val_loss: 445.1983 - val_mae: 445.1983
# Epoch 16/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 405.5244 - mae: 405.5244 - val_loss: 444.9311 - val_mae: 444.9311
# Epoch 17/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 403.5965 - mae: 403.5965 - val_loss: 443.1004 - val_mae: 443.1004
# Epoch 18/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 397.3946 - mae: 397.3946 - val_loss: 443.7353 - val_mae: 443.7353
# Epoch 19/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 391.0266 - mae: 391.0266 - val_loss: 443.8148 - val_mae: 443.8148
# Epoch 20/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 387.7484 - mae: 387.7484 - val_loss: 444.8970 - val_mae: 444.8970
# Epoch 21/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 387.4262 - mae: 387.4262 - val_loss: 448.7259 - val_mae: 448.7259
# Epoch 22/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 393.4742 - mae: 393.4742 - val_loss: 447.4821 - val_mae: 447.4821
# Epoch 23/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 384.0350 - mae: 384.0350 - val_loss: 449.6101 - val_mae: 449.6101
# Epoch 24/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 377.8790 - mae: 377.8790 - val_loss: 449.8698 - val_mae: 449.8698
# Epoch 25/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 378.5746 - mae: 378.5746 - val_loss: 448.1269 - val_mae: 448.1269
# Epoch 26/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 375.7416 - mae: 375.7416 - val_loss: 450.3597 - val_mae: 450.3597
# Epoch 27/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 372.3243 - mae: 372.3243 - val_loss: 450.4075 - val_mae: 450.4075
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# ============================================================
# PIPELINE 1 — GRID SEARCH OPTIMERAD
# ============================================================
# Jämförelse:
#   Original Pipeline 1:   MAE 441.7 SEK, R² 0.447
#   Grid Search Pipeline 1: MAE 440.2 SEK, R² 0.437
#
# Detaljerat:
#   MAE:         440.2 SEK
#   Median AE:   312.9 SEK
#   RMSE:        614.1 SEK
#   MAPE:         41.9 %
#   R²:          0.437

# %%
# Grid search bidrog inte med någon förbättring :(

# %% [markdown]
# ### 2.3 Hur ser fritexten ut?
#
# Några exempel på den ostrukturerade datan modellen arbetar med.

# %%
# Lite exempel på hur vår ostrukturerade data (fritext) kan se ut!
pd.set_option('display.max_colwidth', None)
print(df[['description', 'name', 'amenities', 'neighborhood_overview', 'host_about', 'price']].sample(15))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     description  \
# 1168                                  Hello, hej! Welcome to our cozy 1920s apartment just 15 minutes from Stockholm City Center. Located in the calm and culture-rich area of Gamla Enskede, only a 5-minute walk from the subway. Perfect for families, business travelers, couples, or friends. Close to top restaurants at Slakthusområdet, nature spots like Nackareservatet, and UNESCO-listed Skogskyrkogården. Within walking distance to major arenas (Avicii Arena, 3 Arena, Hovet, Slakthuskyrkan), and 10 minutes from supermarket.
# 3730                                                                                                                                                                                                                  Your family will be close to everything when you stay in this centrally located home.<br /><br />Two minutes to walk to subway. One minute to buses. <br />Close to water and nature. Walking distance to restaurants, cafes and shopping on Södermalm. <br />5 stops on the subway into T-centralen/city without change.
# 4718                                                                                                                                                         Located in the heart of ÖstermalmStockholms most elegant and central neighborhoodthis spacious two-story apartment offers the perfect base for your stay. Enjoy charming streets, beautiful architecture, and walking distance to Strandvägen, Djurgården, top restaurants, cafés, and shops. With excellent public transport nearby, youll have the whole city within easy reach.
# 4261                                                                    Welcome to your cozy home in the heart of Södermalm!<br />This bright, peaceful apartment is ideal for solo travelers, couples, or business guests. Just minutes from subway and bus stations, and close to cafes, restaurants, and attractions.<br /><br /> Comfortable bed<br /> Private bathroom<br /> Equipped kitchen<br /> 5 mins to metro<br /> Quick access to city center<br /><br />Youll have the place to yourself, and Im nearby if you need help or tips!
# 4160  SOCIAL, STYLISH TWO-BEDROOM IN THE MIDDLE OF SOFO<br /><br />A HOST SINCE 2 YEARS & NOW WITH A NEW APARTMENT/LOCATION <br />2-room apartment, thoughtfully planned, high-end and full of smart solutions. The location is (according to us) unbeatable, with Nytorget & SoFo just 5 min away & the ocean is a 1 min walk from the apt. <br /><br />A warm welcome to enjoy your time in Stockholm & we would love to offer you our apartment as your home away from home to unwind in after long days of exploring the capital of Sweden!
# 1261                                                  Welcome to your great home in Old Town close to the Royal Palace and Central Station! Newly renovated, three bedrooms and a living room that can be also used as a bedroom. New kitchen with all necessary cooking tools and equipment, including dishwasher, large dining area.  Two bathrooms, washing machine/dryer. TVs with Netflix. Stable Wi-Fi. The flat is on the ground floor. High ceilings, unique classy & loft style design. A touch of history with no expense on comfort!
# 4744                                                                                                                                                                                                                                                     Central turn-of-the-century apartment, only 10 minutes' walk to the central station. The subway Rådhuset is adjacent to the apartment and also bus line 3 runs just outside. Quiet apartment with windows facing the courtyard. Perfect for a weekend in Stockholm or a business trip.
# 3930                                                                                 Welcome to Stay In Apartments Stockholm, where historic elegance meets modern luxury. Step into this charming apartment featuring high ceilings, vintage long doors, and elegant wooden floors juxtaposed with contemporary furnishings and a fully renovated kitchen. Experience a unique blend of Scandinavian design in every corner. This apartment features one cozy bed and one comfortable sofa bed, ensuring a delightful stay for up to 4 guests.
# 4067                       This cozy apartment is nestled in a quiet courtyard, yet right in the heart of the city, providing the perfect base for exploring. It offers a comfortable bedroom with a 140 cm bed, a living room with a 140 cm sofa bed, and seating for six. The fully equipped kitchen includes a fridge and freezer (no dishwasher), while the bathroom features a bathtub, shower, and WC. A shared laundry room is available on-site. Ideal for both weekend and longer stays, enjoy the vibrant city life with a peaceful r
# 3107                                                                                                                                                                Bring the whole family to this great place with lots of space.<br />You will have access to the whole house as well as 2 bedrooms.  In the house, there are 4 bedrooms in total . You will live by yourself and can use the whole house . ( We close them other 2 bedrooms during your stay.<br />Only booked guests can stay in the property such as Party is not allowed.
# 591                                                                                    Close to nature, water and inner city life. Close to subway station Abrahamsberg, around 10 min with subway to inner city. Balcony facing a green area. The apartment is located at a blind alley so calm with almost no traffic. Double bed in bedroom (160cm) and sofa bed for 2 persons (160 cm) in the living room. Wifi. Kitchen with dishwasher. Bathroom with heated floor. Laundry in the basement. Towels and bed sheets are included. Welcome!
# 3385                                                  Here you live in a quiet room in a quiet and safe area, with the public transports you get into central Stockholm in just 20 minutes. In the neighborhood, there are several grocery stores, cozy cafes and restaurants. The area also borders the appreciated outdoor area Nackareservatet. <br /><br />The host is a high school teacher and is not home often. You have free access to the kitchen and washing machine. If you come by car, you can park for free in the neighborhood.
# 3693                                                                    Cozy basement apartment in villa in Gamla Enskede.<br />Beautiful environment with close proximity to everything! 10 min metro ride to the city as well as 10 min walk to Globen/Avicii Arena and 3 arena.<br />Nice bedroom with bed (105 cm) and work table and dresser.<br />Dining area with kitchenette (no oven) refrigerator and stove. Spacious bathroom with washing machine and shower. A little gem!<br />Small children are in the home so noise may occur.
# 3514                                                                                                                                                                                                              Enjoy a homey accommodation right in the heart of Sofo with greenery outside the windows - a stone's throw from several popular restaurants and cafés. Suitable for a couple, group of friends or family with children with two bedrooms (1.80 cm bed and a bunk bed), spacious living room, kitchen, balcony and a bathroom.
# 156                                                                                                                                                                                                                                                      Our small house is located in a typical villa suburb for families with children and anyone who wants to stay near the big city but still in peace and quiet beyond noise and traffic. Near there is a large playground, a forest with 4km jogging and it is close by to bus and train.
#
#                                                     name  \
# 1168  Modern Apartment 82m2-15 min to Avicii and 3 Arena
# 3730                    Hornstulls mysigaste lilla fyra!
# 4718                 Two-Story Comfort in Prime Location
# 4261         Cozy Central Apartment  5 Min Walk to Metro
# 4160   Central Stockholm - Lovely Apartment popular SoFo
# 1261             Central, Old Town, Large & Luxury Flat!
# 4744                            Ljus sekelskiftslägenhet
# 3930          Stay Inn: Top Floor apartment on Sveavägen
# 4067              Charming and Quiet Courtyard Apartment
# 3107                 Radhus 2 Sovrum Vällingby/Stockholm
# 591    Charming two room apartment. Close to inner city.
# 3385    Tyst och nära till centrala Stockholm och skogen
# 3693  Mysig lägenhet i Gamla Enskede med lummig trädgård
# 3514                           Sekelskifte i en grön oas
# 156                   Lantligt & lugnt nära Älvsjömässan
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             amenities  \
# 1168                                                                                                          ["Cleaning products", "Heating", "Hangers", "Children\u2019s books and toys", "Hot water", "Single level home", "Shampoo", "Dishwasher", "Stove", "Kitchen", "Microwave", "Outdoor dining area", "Iron", "Courtyard view", "Pack \u2019n play/Travel crib - available upon request", "Oven", "Wifi", "Dishes and silverware", "Room-darkening shades", "BBQ grill", "Refrigerator", "Washer", "Coffee maker", "Long term stays allowed", "Hair dryer", "High chair - available upon request", "Cooking basics", "Bed linens", "Shared patio or balcony", "Pets allowed", "Children\u2019s dinnerware", "Dedicated workspace", "Board games", "Baby bath - always at the listing", "HDTV with Chromecast", "Essentials", "Game console: PS4", "Backyard", "Dryer", "Outdoor furniture", "Portable fans"]
# 3730                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ["Waterfront", "Heating", "Hangers", "Hot water kettle", "Hot water", "Dishwasher", "Fire extinguisher", "Smoke alarm", "Kitchen", "Oven", "Wifi", "Beach access", "First aid kit", "Refrigerator", "Washer", "TV", "Hair dryer", "Bed linens", "Freezer", "Dining table", "Toaster"]
# 4718                                                                                                                                                                                                                                                                                                                                                                                           ["Exterior security cameras on property", "Wine glasses", "Heating", "Hot water kettle", "Hot water", "Shampoo", "Dishwasher", "Stove", "Kitchen", "Coffee", "Iron", "Oven", "Wifi", "Dishes and silverware", "Body soap", "Refrigerator", "Washer", "Coffee maker", "Baking sheet", "Hair dryer", "Cooking basics", "Bed linens", "Housekeeping available from 12:00\u202fAM to 5:00\u202fPM, Tuesday to Friday - available at extra cost", "Dining table", "Dryer", "Noise decibel monitors on property", "Toaster"]
# 4261                                                                                                                                                                                                                                             ["Carbon monoxide alarm", "Wine glasses", "Shower gel", "Bathtub", "Hot water kettle", "Drying rack for clothing", "Hot water", "Shampoo", "Ethernet connection", "Fire extinguisher", "Smoke alarm", "Stove", "Kitchen", "Lake access", "Coffee", "Microwave", "Host greets you", "Iron", "Ceiling fan", "Oven", "Wifi", "Dishes and silverware", "Paid parking on premises", "Luggage dropoff allowed", "Body soap", "Trash compactor", "First aid kit", "Blender", "Hair dryer", "Laundromat nearby", "Cooking basics", "Bed linens", "Pets allowed", "Freezer", "Dedicated workspace", "Conditioner", "Essentials", "Cleaning available during stay", "Toaster"]
# 4160                                                                                                                                                              ["Coffee maker: drip coffee maker", "Cleaning products", "Carbon monoxide alarm", "Heating", "Shower gel", "Wine glasses", "Hangers", "Drying rack for clothing", "Hot water", "Air conditioning", "Shampoo", "Dishwasher", "Fire extinguisher", "Smoke alarm", "Kitchen", "Coffee", "Sound system", "Iron", "Oven", "Elevator", "Wifi", "Dishes and silverware", "Self check-in", "Extra pillows and blankets", "Room-darkening shades", "Free dryer \u2013 In unit", "Body soap", "Other stove", "First aid kit", "Exercise equipment", "Washer", "Blender", "Hair dryer", "Private entrance", "Bed linens", "Clothing storage", "Freezer", "Dedicated workspace", "Conditioner", "Bidet", "Dining table", "Smart lock", "Samsung  refrigerator"]
# 1261                                                                                                                                                                                                                                                                                                                                                                                                                                                                ["Waterfront", "Carbon monoxide alarm", "Heating", "Hangers", "Hot water", "City skyline view", "Shampoo", "Dishwasher", "Fire extinguisher", "Smoke alarm", "Stove", "Kitchen", "Microwave", "Iron", "Oven", "Wifi", "Dishes and silverware", "Self check-in", "Extra pillows and blankets", "Keypad", "First aid kit", "Refrigerator", "Washer", "TV", "Hair dryer", "Cooking basics", "Bed linens", "Private entrance", "Essentials", "Dryer"]
# 4744                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ["Smoke alarm", "Kitchen"]
# 3930                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ["Cleaning products", "Heating", "Hangers", "Stove", "Smoke alarm", "Kitchen", "Microwave", "Iron", "Elevator", "Wifi", "Dishes and silverware", "Extra pillows and blankets", "Room-darkening shades", "Refrigerator", "Coffee maker", "TV", "Long term stays allowed", "Bed linens", "Clothing storage", "Essentials", "Dining table", "Dryer"]
# 4067                                                                                                                                                                                                                                                                                                                 ["Cleaning products", "Wine glasses", "Heating", "Shower gel", "Bathtub", "Hangers", "Hot water kettle", "Hot water", "Paid parking off premises", "Shampoo", "Stove", "Fire extinguisher", "Smoke alarm", "Kitchen", "Coffee", "Microwave", "Iron", "Oven", "Elevator", "Wifi", "Dishes and silverware", "Self check-in", "Extra pillows and blankets", "Room-darkening shades", "Body soap", "Refrigerator", "Coffee maker", "TV", "Hair dryer", "Cooking basics", "Bed linens", "Private entrance", "Clothing storage", "Freezer", "Conditioner", "Essentials", "Dining table", "Smart lock"]
# 3107     ["Outdoor playground", "Cleaning products", "Exterior security cameras on property", "Heating", "Wine glasses", "Free street parking", "Bathtub", "Hangers", "Hot water kettle", "Drying rack for clothing", "Hot water", "Shampoo", "Ethernet connection", "Fire extinguisher", "Smoke alarm", "Dishwasher", "Kitchen", "Stove", "Coffee", "Microwave", "Outdoor dining area", "Iron", "Oven", "Wifi", "Dishes and silverware", "Self check-in", "Extra pillows and blankets", "Room-darkening shades", "Body soap", "Beach access", "BBQ grill", "Refrigerator", "Free parking on premises", "Washer", "TV", "Coffee maker", "Hair dryer", "Long term stays allowed", "Cooking basics", "Bed linens", "Private entrance", "Clothing storage", "Freezer", "Dedicated workspace", "Lockbox", "Barbecue utensils", "Essentials", "Dining table", "Dryer", "Outdoor furniture", "Patio or balcony", "Toaster"]
# 591   ["Outdoor playground", "Cleaning products", "Wine glasses", "Heating", "Shower gel", "Shared backyard \u2013 Not fully fenced", "Garden view", "Hangers", "Hot water kettle", "Paid street parking off premises", "Drying rack for clothing", "Hot water", "Shampoo", "Dishwasher", "Fire extinguisher", "Smoke alarm", "Stove", "Kitchen", "Microwave", "Outdoor dining area", "Iron", "Oven", "Wifi", "Dishes and silverware", "Self check-in", "Room-darkening shades", "Hockey rink", "Luggage dropoff allowed", "Body soap", "Free dryer \u2013 In building", "Beach access", "Refrigerator", "Coffee maker", "TV", "Long term stays allowed", "Hair dryer", "Cooking basics", "Bed linens", "Private entrance", "Pets allowed", "Clothing storage", "Free washer \u2013 In building", "Freezer", "Outdoor furniture", "Lockbox", "Conditioner", "Essentials", "Dining table", "Private patio or balcony"]
# 3385                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ["Carbon monoxide alarm", "Dedicated workspace", "Lockbox", "Wifi", "Lock on bedroom door", "Self check-in", "Washer", "TV", "Smoke alarm", "Kitchen", "Pets allowed"]
# 3693                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ["Carbon monoxide alarm", "Heating", "Hot water kettle", "Hot water", "Stove", "Smoke alarm", "Kitchen", "Wifi", "Dishes and silverware", "Extra pillows and blankets", "Refrigerator", "Washer", "Long term stays allowed", "Shared patio or balcony", "Private entrance", "Bed linens", "Dedicated workspace", "Dryer", "Toaster"]
# 3514                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ["Children\u2019s dinnerware", "Iron", "Hangers", "Wifi", "Hot water", "Washer", "TV", "Hair dryer", "Smoke alarm", "Kitchen"]
# 156                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ["Host greets you", "Heating", "Wifi", "TV", "Kitchen"]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          neighborhood_overview  \
# 1168                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Welcome to Gamla Enskede, your charming apartment away from home in the heart of Stockholm! Our cozy neighborhood is the perfect place to relax and unwind during your visit to this beautiful city.<br /><br />Our lovely apartment is located in the heart of Gamla Enskede, just a short walk from the picturesque Enskede Park. <br /><br />Whether you're here to explore Stockholm's many attractions or simply to unwind and relax, Gamla Enskede is the perfect place to call home during your visit. We look forward to welcoming you soon!
# 3730                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     okänt
# 4718                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Östermalm is an upscale district in the heart of Stockholm, known for its elegant architecture, exclusive designer boutiques and vibrant nightclubs around Stureplan. Whether you are here for business or leisure, its an ideal base for exploring the city.<br /><br />The district boasts charming streets lined with gourmet restaurants, the lush park of Humlegården and iconic landmarks like the Royal Dramatic Theatre. A visit to Östermalms Saluhall, a covered market hall rich in history, is a must for food lovers.
# 4261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     okänt
# 4160                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     okänt
# 1261                                                                                                                                                                                                                                                                                                                                                                             The flat is located in the heart of the Old Town - Gamla Stan, which is the very center of Stockholm, next to the Royal Palace.  Few minutes walk to the Metro (Gamla Stan), less than 10 min walk to Central Station (T-Centralen) and the City with the largest shopping centers. Few minutes walk to Södermalm with various bars, restaurants, and nightlife. The shops, tourist streets, many restaurants, and cafes are just downstairs. All major sites of attractions are around the corner or within the walking distance. Close to the waterside, embankment and stunning views. It is hard to imagine a better location for your stay in Stockholm!
# 4744                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     okänt
# 3930  Nearby Restaurants and Cafés<br /><br />Burgers and Beer<br />Just 1 minute away<br />A neighborhood favorite for juicy burgers, crispy fries and craft beer. Casual, reliable and always satisfying.<br /><br /><br />Bar Nombre<br />7 minutes away<br />Stylish and modern Spanish restaurant offering tapas, wine and creative cocktails. Great for date night or group dinners.<br /><br /><br />Farang<br />12 minutes away by foot or a quick ride<br />Modern Southeast Asian fine dining in a stylish, industrial-chic setting. Bold flavors, elegant presentation and a standout tasting menu make this a must-visit for food lovers.<br /><br /><br />Savant Vinbar<br />10 minutes away<br />A beautiful, minimalistic natural wine bar with a rotating wine list and light seasonal dishes. Cozy, intimate and effortlessly cool.<br /><br /><br />Lennart & Bror Fisk<br />Around 12 minutes by foot<br />A small seafood-focused spot known for its freshness, simplicity and expert preparation. Great for oysters, crud
# 4067                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Located in a prime spot, this well-positioned apartment offers easy access to vibrant shopping streets, pubs, bars, and scenic green spaces. From here, you can effortlessly explore all that Stockholm has to offer. Just a short walk to the renowned café "Mr. Cake," famous for serving some of the best "fika" in the city. In only ten minutes, you can reach Odenplan, a lively hub with everything you need, including a transportation center, grocery stores, pharmacies, and much more.
# 3107                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     okänt
# 591                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Close to nature, water and nice jogging tracks.
# 3385                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     okänt
# 3693                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     okänt
# 3514                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     okänt
# 156                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      okänt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           host_about  \
# 1168                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Hi there!\nI'm Maria from Stockholm, Sweden. Im a certified sleep coach for children and have been running my own business since 2020.\n\nI love interior design, literature, nature, ceramics  and being close to water. Traveling is also a big passion of mine, especially around Europe and the US.  I live with my husband Kenny and our daughter Maya in a calm and charming neighborhood called Enskede, in Stockholm
# 3730                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           okänt
# 4718                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Hi, \r\n\r\nI love traveling and meeting new people. Originally from the Northern parts of Sweden, I spend a lot of times skiing and playing winter sports. Experienced host working in the hospitality and logistics industry.\r\n\r\nSee you
# 4261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        A world traveler with a love for new experiences! Im passionate about discovering new places, trying local foods, and meeting interesting people. For me, travel isnt just about seeing new places, but about creating special memories.
# 4160                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       World traveler from Sweden - have lived on different continents but are now based in Stockholm full-time. My favorites places in the world is South Africa and Sri Lanka!
# 1261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Hi! My name is Inna -\r\nI love to travel around the world and meet new people!
# 4744                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           okänt
# 3930                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Welcome to Stay Inn Apartments!\n\nExperience comfort and unbeatable locations with Stay Inn Airbnb rentals. As city enthusiasts, we specialize in offering urban retreats that provide the perfect base for exploring vibrant city life. Our focus is on comfortable and well-located accommodations that prioritize convenience and accessibility to top attractions.
# 4067                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     My co-hosts and I will do our utmost to ensure you have a wonderful time here in Stockholm!
# 3107                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           okänt
# 591                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Welcome home!
# 3385                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Jag kommer att kunna ge dig värdefulla tips på vad du kan se och göra i Stockholm samt tips på bra restauranger och caféer längs den gröna linjen.\nOm dagarna är jag lärare på gymnasiet. Under åren har jag rest i till nästan 80 länder och jag jobbar på att en dag ska kunna berätta att jag har varit i över 100 länder.
# 3693                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              I'm an architect and designer from Stockholm. I speak fluent swedish, english, french and italian.
# 3514                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           okänt
# 156   I am a teacher and interested in travelling abroad to Spain/Germany/Switzerland etc ad speak foreign languages. I have room for up to five people in my house, the smallest room costs less, the bigger ones more. I have had Spanish, German, English and Japanese even Finnish guests and many more =). I enjoy my life in Sweden in the winter by dancing rock´nd roll, skiing in the north, hiking in the surroundings and athletics. I can always introduce my guests to my gym, one time Free!  I go to gardening fairs in Scania, love cooking and do it together my guests as well. I enjoy films (have you seen W.E?) or the Swedish "Sunes sommar"not to talk about Bergman´s Fanny and Alexander or Stieg Larssons trilogy, comedies and music- at the moment the becoming European contest, My interest in shopping is focused on vintage. I prefer jogging and nature, riding is for my daughter, climbing for my son and design and museums, cafés are on my list and I would like to show you Stockholm if you are looking for a guide or perhaps just company during your visit to our beautiful Old Town. My life motto is everything is possible. I welcome you to join to stay in our house! It is a great pleasure for me!
#
#        price
# 1168   723.0
# 3730  1858.0
# 4718  1945.0
# 4261   964.0
# 4160  1905.0
# 1261  3723.0
# 4744  1334.0
# 3930  1204.0
# 4067  1382.0
# 3107   969.0
# 591    800.0
# 3385   400.0
# 3693   720.0
# 3514  2143.0
# 156   2500.0

# %% [markdown]
# ### 2.4 Feature importance — vilka ord påverkar priset?
#
# Med **permutation importance** mäter vi hur mycket modellen försämras när vi slumpar (förstör) ett enskilt ord. Stort tapp = viktigt ord. Eftersom Keras-modellen inte direkt fungerar med scikit-learns verktyg använder vi en `KerasRegressorWrapper` — samma teknik som i kursmaterialet, men anpassad för regression istället för klassificering.
#
# **Viktigt:** permutation importance säger hur *viktig* en feature är — inte åt vilket håll den drar priset. Det undersöker vi separat längre ner.

# %%
# ============================================================
# PERMUTATION IMPORTANCE — Pipeline 1 (bara text)
# ============================================================

from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.inspection import permutation_importance

# ============================================================
# Wrapper (samma som tidigare)
# ============================================================
class KerasRegressorWrapper(BaseEstimator, RegressorMixin):
    def __init__(self, keras_model):
        self.keras_model = keras_model
    
    def fit(self, X, y):
        pass
    
    def predict(self, X):
        return self.keras_model.predict(X, verbose=0).flatten()

# ============================================================
# Wrappa text-modellen och kör permutation
# ============================================================
wrapped_text = KerasRegressorWrapper(model_text)

print("Kör permutation importance på Pipeline 1 (kan ta några minuter)...")
result_text = permutation_importance(
    wrapped_text, X_test_text, y_test,
    scoring="neg_mean_absolute_error",
    n_repeats=10,
    random_state=42)

# ============================================================
# Sammanställ feature-namn
# ============================================================
# OBS: I Pipeline 1 finns BARA text-features — inga numeriska eller kategoriska
text_feature_names = []
text_field_lookup = {}  # word → vilket textfält

for col in tfidf_settings.keys():
    words = tfidf_vectorizers[col].get_feature_names_out().tolist()
    for w in words:
        text_feature_names.append(w)
        text_field_lookup[(col, w)] = True
    
# För att veta vilket fält varje feature kommer från, bygg en index-baserad lookup
field_per_idx = []
for col in tfidf_settings.keys():
    n = tfidf_vectorizers[col].get_feature_names_out().shape[0]
    field_per_idx.extend([col] * n)

# ============================================================
# Bygg DataFrame
# ============================================================
fi_text = pd.DataFrame({
    "ord":        text_feature_names,
    "textfält":   field_per_idx,
    "importance": result_text.importances_mean,
    "std":        result_text.importances_std,
})

fi_text = fi_text.sort_values("importance", ascending=False).reset_index(drop=True)

print("\n" + "=" * 70)
print("PIPELINE 1 — TOPP 30 VIKTIGASTE ORD")
print("=" * 70)
print(fi_text.head(30).to_string(index=False))
# Out:
# Kör permutation importance på Pipeline 1 (kan ta några minuter)...
#
# ======================================================================
# PIPELINE 1 — TOPP 30 VIKTIGASTE ORD
# ======================================================================
#         ord              textfält  importance      std
#        room                  name   17.955124 2.083987
#       okänt            host_about   16.478192 2.585268
#       villa                  name    8.415973 1.940195
#       okänt neighborhood_overview    7.667044 1.785458
#    bedrooms           description    7.396021 1.581388
#          tv             amenities    7.180408 1.401363
#    children             amenities    5.960815 2.092777
#      family           description    5.616626 2.019014
#        lock             amenities    5.580032 1.379217
#         rum                  name    4.364285 1.479504
#        crib             amenities    3.548907 1.543442
#  dishwasher             amenities    3.544733 1.500695
#       large           description    3.420697 0.811129
#          på                  name    3.221271 2.023381
#      u2019s             amenities    3.219559 1.310065
#       books             amenities    3.098291 0.972670
#   södermalm                  name    3.073151 1.345269
#     bathtub             amenities    2.736728 1.557179
#       rooms           description    2.575113 0.668222
#        beds           description    2.556165 0.745551
#       house           description    2.521405 1.087698
#   penthouse                  name    2.517371 0.875156
#      studio           description    2.405890 1.577653
#        stor                  name    2.383374 0.888043
#       local neighborhood_overview    2.261627 0.784600
#        view             amenities    2.245050 1.044932
#    elevator             amenities    2.019046 1.173222
#      dining           description    1.975189 0.792454
#        stay            host_about    1.903784 1.017270
# conditioner             amenities    1.864435 0.641693

# %%
# Färgkoda efter textfält
top_words = fi_text.head(25).iloc[::-1]

color_map_fields = {
    "name":                  "#1D9E75",
    "description":           "#85B7EB",
    "amenities":             "#AFA9EC",
    "neighborhood_overview": "#D85A30",
    "host_about":            "#EF9F27",
}
colors = [color_map_fields[f] for f in top_words["textfält"]]

fig, ax = plt.subplots(figsize=(11, 9))
bars = ax.barh(top_words["ord"], top_words["importance"],
               xerr=top_words["std"], color=colors, edgecolor="black", alpha=0.85)

ax.set_xlabel("Permutation Importance (MAE-ökning, SEK)")
ax.set_title("Pipeline 1: Topp 25 viktigaste ord (bara text)")
ax.grid(True, alpha=0.3, axis="x")

# Legend
from matplotlib.patches import Patch
legend_items = [Patch(color=c, label=f) for f, c in color_map_fields.items()]
ax.legend(handles=legend_items, loc="lower right", title="Textfält")

plt.tight_layout()
plt.show()

# %%
# ============================================================
# Topp 5 ord per textfält — vilka är "guldorden" i varje fält?
# ============================================================
print("\n" + "=" * 60)
print("TOPP 5 ORD PER TEXTFÄLT")
print("=" * 60)

for fält in tfidf_settings.keys():
    sub = fi_text[fi_text["textfält"] == fält].head(5)
    if len(sub) > 0:
        print(f"\n{fält}:")
        for _, row in sub.iterrows():
            print(f"  '{row['ord']}': {row['importance']:.2f} SEK")
# Out:
# ============================================================
# TOPP 5 ORD PER TEXTFÄLT
# ============================================================
#
# name:
#   'room': 17.96 SEK
#   'villa': 8.42 SEK
#   'rum': 4.36 SEK
#   'på': 3.22 SEK
#   'södermalm': 3.07 SEK
#
# description:
#   'bedrooms': 7.40 SEK
#   'family': 5.62 SEK
#   'large': 3.42 SEK
#   'rooms': 2.58 SEK
#   'beds': 2.56 SEK
#
# amenities:
#   'tv': 7.18 SEK
#   'children': 5.96 SEK
#   'lock': 5.58 SEK
#   'crib': 3.55 SEK
#   'dishwasher': 3.54 SEK
#
# neighborhood_overview:
#   'okänt': 7.67 SEK
#   'local': 2.26 SEK
#   'br': 1.70 SEK
#   'minutes': 1.09 SEK
#   'area': 0.74 SEK
#
# host_about:
#   'okänt': 16.48 SEK
#   'stay': 1.90 SEK
#   'experience': 1.61 SEK
#   'people': 1.22 SEK
#   'apartments': 1.17 SEK

# %%
"""
Värdet 6.26 SEK för okänt betyder:
Om jag förstör denna feature blir modellen 6.26 SEK sämre.

Det säger inget om dyrt eller billigt.
Permutation importance är som att fråga hur viktig är termometern i bilen? — svaret säger inget om det är varmt eller kallt ute. Bara att informationen är värd att ha.
"""
# Out:
# '\nVärdet 6.26 SEK för okänt betyder:\nOm jag förstör denna feature blir modellen 6.26 SEK sämre.\n\nDet säger inget om dyrt eller billigt.\nPermutation importance är som att fråga hur viktig är termometern i bilen? — svaret säger inget om det är varmt eller kallt ute. Bara att informationen är värd att ha.\n'

# %% [markdown]
# ### 2.5 Åt vilket håll drar orden priset?
#
# Permutation importance visar *att* ett ord är viktigt. För att se *åt vilket håll* jämför vi medelpriset för listings som innehåller ordet mot de som inte gör det. Här framträder konkreta affärsinsikter — t.ex. att ordet *family* i beskrivningen hänger ihop med betydligt dyrare bostäder (eftersom det signalerar större lägenheter).

# %%
ord_att_testa = [
    ("host_about",            "okänt"),
    ("neighborhood_overview", "okänt"),
    ("name",                  "private"),
    ("amenities",             "lockbox"),
    ("amenities",             "elevator"),
    ("amenities",             "washer"),
    ("description",           "subway"),
    ("description",           "family"),
]

print(f"{'Fält':25s} {'Ord':15s} {'Med':>8s} {'Utan':>8s} {'Diff':>8s}")
print("-" * 70)
for fält, ord in ord_att_testa:
    mask = df[fält].str.lower().str.contains(ord, na=False)
    med  = df.loc[mask, "price"].mean()
    utan = df.loc[~mask, "price"].mean()
    diff = med - utan
    print(f"{fält:25s} {ord:15s} {med:>8.0f} {utan:>8.0f} {diff:>+8.0f}")
# Out:
# Fält                      Ord                  Med     Utan     Diff
# ----------------------------------------------------------------------
# host_about                okänt               1408     1313      +95
# neighborhood_overview     okänt               1313     1449     -135
# name                      private             1205     1367     -162
# amenities                 lockbox             1344     1367      -23
# amenities                 elevator            1358     1364       -6
# amenities                 washer              1437     1113     +324
# description               subway              1317     1376      -59
# description               family              1827     1302     +525

# %% [markdown]
# > **Insikt om ordet "okänt":** Ett av de mest prediktiva "orden" visade sig vara vår egen platshållare `okänt`, som vi fyllde tomma textfält med. Modellen lärde sig alltså att *frånvaron* av text är prediktiv — värdar som inte skriver något om sig själva är ofta förvaltningsbolag med något dyrare listings. Detta är ett klassiskt ML-fenomen: modellen plockar upp en **proxy för datakvalitet** snarare än ett verkligt språkligt mönster. Signalen är legitim, men illustrerar vikten av att granska sin egen modell kritiskt.

# %% [markdown]
# ## 3. Pipeline 2 — Text + numeriska + kategoriska variabler
#
# Nu utökar vi modellen med all tillgänglig strukturerad data. Vi behåller TF-IDF-featurena från textfälten och lägger till:
#
# - **Numeriska features:** antal rum, badrum, kapacitet, recensionspoäng, koordinater, tillgänglighet m.m.
# - **Kategoriska features:** `property_type`, `room_type`, stadsdel och svarstid, omvandlade till heltal med `LabelEncoder`.
# - **Booleska features:** superhost, verifierad identitet m.m. som 0/1.
#
# Allt kombineras till en enda feature-matris som matas in i samma typ av Sequential-nätverk som i Pipeline 1.

# %%
# Utökad pipeline, lägg till numeriska och kategoriska variabler till modellen!

# %%
# ============================================================
# PIPELINE 2: TEXT + NUMERISKA + KATEGORISKA
# Återanvänder TF-IDF från Pipeline 1
# Lägger till numeriska och kategoriska features
# ============================================================

from sklearn.preprocessing import StandardScaler, LabelEncoder
from scipy.sparse import hstack, csr_matrix

# ============================================================
# STEG 1: Definiera kolumngrupper
# ============================================================
cat_cols = ["property_type", "room_type",
            "neighbourhood_cleansed", "host_response_time"]

num_cols = [
    "bedrooms", "bathrooms", "beds", "accommodates",
    "minimum_nights", "maximum_nights",
    "number_of_reviews", "number_of_reviews_ltm", "reviews_per_month",
    "review_scores_rating", "review_scores_accuracy",
    "review_scores_cleanliness", "review_scores_checkin",
    "review_scores_communication", "review_scores_location",
    "review_scores_value",
    "latitude", "longitude",
    "availability_30", "availability_60",
    "availability_90", "availability_365",
    "host_listings_count", "calculated_host_listings_count",
]

bool_cols = ["host_is_superhost", "host_has_profile_pic",
             "host_identity_verified", "instant_bookable",
             "has_availability"]

# ============================================================
# STEG 2: Procent-strängar och datum
# (df är samma som från Pipeline 1)
# ============================================================
def parse_pct(s):
    return pd.to_numeric(
        s.astype(str).str.rstrip("%").str.strip().replace("", np.nan),
        errors="coerce") / 100

df["host_response_rate"]   = parse_pct(df["host_response_rate"])
df["host_acceptance_rate"] = parse_pct(df["host_acceptance_rate"])
num_cols += ["host_response_rate", "host_acceptance_rate"]

df["host_since"] = pd.to_datetime(df["host_since"], errors="coerce")
df["host_age_days"] = (pd.Timestamp.now() - df["host_since"]).dt.days
num_cols += ["host_age_days"]

# ============================================================
# STEG 3: Booleans → 0/1
# ============================================================
for c in bool_cols:
    df[c] = (df[c].astype(str).str.strip().str.lower() == "t").astype(int)
num_cols += bool_cols

# ============================================================
# STEG 4: Kategoriska → LabelEncode
# ============================================================
encoders = {}
for c in cat_cols:
    df[c] = df[c].fillna("okänt").astype(str)
    le = LabelEncoder()
    df[c + "_enc"] = le.fit_transform(df[c])
    encoders[c] = le

cat_enc_cols = [c + "_enc" for c in cat_cols]

# ============================================================
# STEG 5: Numeriska — tvinga till tal, fyll median
# ============================================================
for c in num_cols:
    df[c] = pd.to_numeric(df[c], errors="coerce")
    df[c] = df[c].fillna(df[c].median())

# ============================================================
# STEG 6: Stryp outliers i features
# ============================================================
df = df[df["bedrooms"].between(0, 10)]
df = df[df["bathrooms"].between(0, 10)]
df = df[df["accommodates"].between(1, 20)]
df = df[df["minimum_nights"].between(1, 365)]

print(f"Efter all rensning: {len(df)} rader kvar")

# ============================================================
# STEG 7: Splitta OM (samma random_state = samma split)
# ============================================================
y = df[target].values.astype("float32")

X_train_df, X_test_df, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42)

print(f"Train: {len(X_train_df)}, Test: {len(X_test_df)}")

# ============================================================
# STEG 8: Bygg om TF-IDF (nya rader = nytt vokabulär)
# ============================================================
print("\nBygger TF-IDF-vektorer...")

tfidf_train = []
tfidf_test = []

for col, max_feat in tfidf_settings.items():
    tfidf = TfidfVectorizer(
        max_features=max_feat,
        stop_words="english",
        lowercase=True,
        min_df=5,
        ngram_range=(1, 1))
    
    train_vec = tfidf.fit_transform(X_train_df[col].values)
    test_vec  = tfidf.transform(X_test_df[col].values)
    
    tfidf_train.append(train_vec)
    tfidf_test.append(test_vec)
    print(f"  {col:25s}: {train_vec.shape[1]:>3} features")

# ============================================================
# STEG 9: Skala numeriska
# ============================================================
scaler = StandardScaler()
X_train_num = scaler.fit_transform(X_train_df[num_cols]).astype("float32")
X_test_num  = scaler.transform(X_test_df[num_cols]).astype("float32")

# ============================================================
# STEG 10: Kombinera ALLT till en matris
# ============================================================
X_train_num_sp = csr_matrix(X_train_num)
X_test_num_sp  = csr_matrix(X_test_num)

X_train_cat_sp = csr_matrix(X_train_df[cat_enc_cols].values.astype("float32"))
X_test_cat_sp  = csr_matrix(X_test_df[cat_enc_cols].values.astype("float32"))

X_train_full = hstack([X_train_num_sp, X_train_cat_sp] + tfidf_train).toarray().astype("float32")
X_test_full  = hstack([X_test_num_sp,  X_test_cat_sp]  + tfidf_test).toarray().astype("float32")

print(f"\nFinal feature matrix:")
print(f"  Train: {X_train_full.shape}")
print(f"  Numerisk: {len(num_cols)}, Kategorisk: {len(cat_enc_cols)}, Text: {sum(t.shape[1] for t in tfidf_train)}")

# ============================================================
# STEG 11: Bygg samma Sequential modell
# ============================================================
model_full = tf.keras.models.Sequential([
    tf.keras.Input(shape=(X_train_full.shape[1],)),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(64, activation="relu"),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(1)
])

model_full.compile(
    optimizer="adam",
    loss="mae",
    metrics=["mae"])

print(f"\nModell — antal parametrar: {model_full.count_params():,}")

# ============================================================
# STEG 12: Träna
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=10, restore_best_weights=True)

history_full = model_full.fit(
    X_train_full, y_train,
    validation_data=(X_test_full, y_test),
    epochs=100, batch_size=32,
    callbacks=[early_stop],
    verbose=1)

# ============================================================
# STEG 13: Utvärdera Pipeline 2 (alla mätvärden direkt)
# ============================================================
y_pred_full = model_full.predict(X_test_full).flatten()

mae_full   = np.mean(np.abs(y_pred_full - y_test))
rmse_full  = np.sqrt(np.mean((y_pred_full - y_test) ** 2))
medae_full = np.median(np.abs(y_test - y_pred_full))
mape_full  = np.mean(np.abs((y_test - y_pred_full) / y_test)) * 100
r2_full    = r2_score(y_test, y_pred_full)

mean_pred = y_train.mean()
mae_base = np.mean(np.abs(y_test - mean_pred))

print("\n" + "=" * 50)
print("PIPELINE 2 — ALLT TILLSAMMANS")
print("=" * 50)
print(f"Antal features:        {X_train_full.shape[1]}")
print(f"  varav numeriska:     {len(num_cols)}")
print(f"  varav kategoriska:   {len(cat_enc_cols)}")
print(f"  varav text (TF-IDF): {sum(t.shape[1] for t in tfidf_train)}")
print(f"")
print(f"MAE 'gissa medel':     {mae_base:.1f} SEK")
print(f"MAE pipeline 1 (text): 441.7 SEK")
print(f"MAE pipeline 2 (allt): {mae_full:.1f} SEK")
print(f"RMSE:                  {rmse_full:.1f} SEK")
print(f"Median AE:             {medae_full:.1f} SEK")
print(f"MAPE:                  {mape_full:.1f} %")
print(f"R²:                    {r2_full:.3f}")
print(f"Relativt fel:          {mae_full/y_test.mean()*100:.1f}%")

# ============================================================
# STEG 14: Plotta loss
# ============================================================
plt.figure(figsize=(10, 4))
plt.plot(history_full.history["loss"], label="Training loss")
plt.plot(history_full.history["val_loss"], label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("MAE (SEK)")
plt.title("Pipeline 2: Loss över epochs (text + numerisk + kategorisk)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Efter all rensning: 3027 rader kvar
# Train: 2421, Test: 606
#
# Bygger TF-IDF-vektorer...
#   name                     : 100 features
#   description              : 200 features
#   amenities                : 100 features
#   neighborhood_overview    :  50 features
#   host_about               :  50 features
#
# Final feature matrix:
#   Train: (2421, 536)
#   Numerisk: 32, Kategorisk: 4, Text: 500
#
# Modell — antal parametrar: 79,105
# Epoch 1/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1216.4429 - mae: 1216.4429 - val_loss: 779.3351 - val_mae: 779.3351
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 668.8979 - mae: 668.8979 - val_loss: 567.3188 - val_mae: 567.3188
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 512.1372 - mae: 512.1372 - val_loss: 454.9460 - val_mae: 454.9460
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 430.6039 - mae: 430.6039 - val_loss: 422.5141 - val_mae: 422.5141
# Epoch 5/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 415.5943 - mae: 415.5943 - val_loss: 403.8625 - val_mae: 403.8625
# Epoch 6/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 403.2646 - mae: 403.2646 - val_loss: 396.4648 - val_mae: 396.4648
# Epoch 7/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 387.7440 - mae: 387.7440 - val_loss: 384.4891 - val_mae: 384.4891
# Epoch 8/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 377.1736 - mae: 377.1736 - val_loss: 379.2617 - val_mae: 379.2617
# Epoch 9/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 366.2645 - mae: 366.2645 - val_loss: 374.8817 - val_mae: 374.8817
# Epoch 10/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 366.7906 - mae: 366.7906 - val_loss: 372.0349 - val_mae: 372.0349
# Epoch 11/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 357.8649 - mae: 357.8649 - val_loss: 368.9456 - val_mae: 368.9456
# Epoch 12/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 357.0713 - mae: 357.0713 - val_loss: 369.9807 - val_mae: 369.9807
# Epoch 13/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 354.5166 - mae: 354.5166 - val_loss: 367.5712 - val_mae: 367.5712
# Epoch 14/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 344.9210 - mae: 344.9210 - val_loss: 365.0342 - val_mae: 365.0342
# Epoch 15/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 345.9828 - mae: 345.9828 - val_loss: 365.5241 - val_mae: 365.5241
# Epoch 16/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 341.8888 - mae: 341.8888 - val_loss: 365.9830 - val_mae: 365.9830
# Epoch 17/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 342.7609 - mae: 342.7609 - val_loss: 361.6818 - val_mae: 361.6818
# Epoch 18/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 337.9001 - mae: 337.9001 - val_loss: 364.1026 - val_mae: 364.1026
# Epoch 19/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 340.9394 - mae: 340.9394 - val_loss: 362.3826 - val_mae: 362.3826
# Epoch 20/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 328.7269 - mae: 328.7269 - val_loss: 361.3344 - val_mae: 361.3344
# Epoch 21/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 332.9251 - mae: 332.9251 - val_loss: 371.6316 - val_mae: 371.6316
# Epoch 22/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 321.7892 - mae: 321.7892 - val_loss: 368.7605 - val_mae: 368.7605
# Epoch 23/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 318.6304 - mae: 318.6304 - val_loss: 359.9589 - val_mae: 359.9589
# Epoch 24/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 324.2956 - mae: 324.2956 - val_loss: 359.1720 - val_mae: 359.1720
# Epoch 25/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 321.8141 - mae: 321.8141 - val_loss: 360.3870 - val_mae: 360.3870
# Epoch 26/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 318.4121 - mae: 318.4121 - val_loss: 361.0282 - val_mae: 361.0282
# Epoch 27/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 322.2948 - mae: 322.2948 - val_loss: 360.6768 - val_mae: 360.6768
# Epoch 28/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 316.9168 - mae: 316.9168 - val_loss: 358.7878 - val_mae: 358.7878
# Epoch 29/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 318.6130 - mae: 318.6130 - val_loss: 365.8061 - val_mae: 365.8061
# Epoch 30/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 310.0888 - mae: 310.0888 - val_loss: 364.2494 - val_mae: 364.2494
# Epoch 31/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 308.4556 - mae: 308.4556 - val_loss: 365.6818 - val_mae: 365.6818
# Epoch 32/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 304.4648 - mae: 304.4648 - val_loss: 369.4037 - val_mae: 369.4037
# Epoch 33/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 307.2151 - mae: 307.2151 - val_loss: 367.3696 - val_mae: 367.3696
# Epoch 34/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 309.9285 - mae: 309.9285 - val_loss: 363.7859 - val_mae: 363.7859
# Epoch 35/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 308.1634 - mae: 308.1634 - val_loss: 363.5049 - val_mae: 363.5049
# Epoch 36/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 302.1353 - mae: 302.1353 - val_loss: 362.1832 - val_mae: 362.1832
# Epoch 37/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 299.8930 - mae: 299.8930 - val_loss: 360.6403 - val_mae: 360.6403
# Epoch 38/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 306.1552 - mae: 306.1552 - val_loss: 364.2716 - val_mae: 364.2716
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# ==================================================
# PIPELINE 2 — ALLT TILLSAMMANS
# ==================================================
# Antal features:        536
#   varav numeriska:     32
#   varav kategoriska:   4
#   varav text (TF-IDF): 500
#
# MAE 'gissa medel':     663.9 SEK
# MAE pipeline 1 (text): 441.7 SEK
# MAE pipeline 2 (allt): 358.8 SEK
# RMSE:                  514.8 SEK
# Median AE:             237.5 SEK
# MAPE:                  28.4 %
# R²:                    0.614
# Relativt fel:          26.2%

# %% [markdown]
# ### 3.1 Feature importance för hela modellen
#
# Vi kör permutation importance på den fulla modellen och grupperar resultatet per feature-typ. Detta besvarar frågan: **vilken typ av data bär mest prediktiv kraft — text, numeriska eller kategoriska?**

# %%
# ============================================================
# PERMUTATION IMPORTANCE — Pipeline 2 (allt)
# Modifierad för regression istället för klassificering
# ============================================================

from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.inspection import permutation_importance

# ============================================================
# Wrapper-klass (samma struktur som kursen, men för regression)
# ============================================================
class KerasRegressorWrapper(BaseEstimator, RegressorMixin):
    # I kursen var det ClassifierMixin — för regression använder vi RegressorMixin
    
    def __init__(self, keras_model):
        self.keras_model = keras_model
    
    def fit(self, X, y):
        # Modellen är redan tränad
        pass
    
    def predict(self, X):
        # Returnera kontinuerligt värde direkt (ingen argmax)
        return self.keras_model.predict(X, verbose=0).flatten()

# ============================================================
# Sätt upp permutation importance
# ============================================================
wrapped_model = KerasRegressorWrapper(model_full)

print("Kör permutation importance (kan ta några minuter)...")
result = permutation_importance(
    wrapped_model, X_test_full, y_test,
    scoring="neg_mean_absolute_error",   # för regression
    n_repeats=10,
    random_state=42)

# ============================================================
# Sammanställ feature-namn (samma ordning som i matrisen)
# ============================================================
# Ordning i X_train_full: [numeric, cat, tfidf...]
feature_names = (
    num_cols +                                    # 32 numeriska
    cat_enc_cols +                                # 4 kategoriska
    list(tfidf_vectorizers["name"].get_feature_names_out()) +
    list(tfidf_vectorizers["description"].get_feature_names_out()) +
    list(tfidf_vectorizers["amenities"].get_feature_names_out()) +
    list(tfidf_vectorizers["neighborhood_overview"].get_feature_names_out()) +
    list(tfidf_vectorizers["host_about"].get_feature_names_out())
)

# Prefixa text-features för att göra dem distinkta
text_field_offsets = []
offset = len(num_cols) + len(cat_enc_cols)
for col in tfidf_settings.keys():
    n_features = tfidf_vectorizers[col].get_feature_names_out().shape[0]
    text_field_offsets.append((col, offset, offset + n_features))
    offset += n_features

# Skapa kategori-etikett per feature
def get_category(idx):
    if idx < len(num_cols):
        return "Numerisk"
    elif idx < len(num_cols) + len(cat_enc_cols):
        return "Kategorisk"
    else:
        for col, start, end in text_field_offsets:
            if start <= idx < end:
                return f"Text ({col})"
    return "Okänd"

# ============================================================
# Bygg DataFrame
# ============================================================
fi_df = pd.DataFrame({
    "feature":    feature_names,
    "importance": result.importances_mean,
    "std":        result.importances_std,
    "kategori":   [get_category(i) for i in range(len(feature_names))],
})

# Sortera efter importance (störst först)
fi_df = fi_df.sort_values("importance", ascending=False).reset_index(drop=True)

print("\n" + "=" * 60)
print("TOPP 20 FEATURES")
print("=" * 60)
print(fi_df.head(20).to_string(index=False))
# Out:
# Kör permutation importance (kan ta några minuter)...
#
# ============================================================
# TOPP 20 FEATURES
# ============================================================
#                        feature  importance      std                     kategori
#                   accommodates   63.987585 5.775790                     Numerisk
#                       bedrooms   58.496466 5.600101                     Numerisk
#                      longitude   38.168631 4.799862                     Numerisk
#                  room_type_enc   38.070770 7.556642                   Kategorisk
#                 minimum_nights   20.829062 2.713891                     Numerisk
#                       latitude   18.654367 4.068388                     Numerisk
#         review_scores_location   12.699774 3.051855                     Numerisk
#                availability_30   11.214017 2.594962                     Numerisk
#            review_scores_value   10.892535 1.916908                     Numerisk
#                            och   10.173328 2.394119            Text (host_about)
#              reviews_per_month    8.798270 1.532670                     Numerisk
#                          okänt    7.592972 1.984294 Text (neighborhood_overview)
#               availability_365    6.529401 1.798611                     Numerisk
#                             tv    5.589505 1.516981             Text (amenities)
#              property_type_enc    5.588034 3.813695                   Kategorisk
#          number_of_reviews_ltm    5.563037 1.545700                     Numerisk
# calculated_host_listings_count    5.289981 2.052708                     Numerisk
#           review_scores_rating    4.437479 2.689504                     Numerisk
#     neighbourhood_cleansed_enc    3.965524 1.220275                   Kategorisk
#           host_acceptance_rate    3.411826 1.187500                     Numerisk

# %%
# Topp 20
top = fi_df.head(20).iloc[::-1]  # vänd för plot

# Färgkoda efter kategori
def short_cat(c):
    if c.startswith("Text"): return "Text"
    return c

top["short_kat"] = top["kategori"].apply(short_cat)

color_map = {"Numerisk": "#1D9E75", "Kategorisk": "#85B7EB", "Text": "#AFA9EC"}
colors = [color_map[c] for c in top["short_kat"]]

fig, ax = plt.subplots(figsize=(10, 8))
bars = ax.barh(top["feature"], top["importance"],
               xerr=top["std"], color=colors, edgecolor="black", alpha=0.85)

ax.set_xlabel("Permutation Importance (MAE-ökning)")
ax.set_title("Pipeline 2: Topp 20 features")
ax.grid(True, alpha=0.3, axis="x")

# Legend
from matplotlib.patches import Patch
legend = [Patch(color=c, label=t) for t, c in color_map.items()]
ax.legend(handles=legend, loc="lower right")

plt.tight_layout()
plt.show()

# %%
# Summera per kategori
fi_df["kategori_grov"] = fi_df["kategori"].apply(short_cat)
summary = fi_df.groupby("kategori_grov")["importance"].agg(
    ["sum", "mean", "count"]
).sort_values("sum", ascending=False)

print("\n" + "=" * 50)
print("SUMMERAT PER KATEGORI")
print("=" * 50)
print(summary)

# Andel av total importance
total = fi_df["importance"].sum()
summary["andel_%"] = (summary["sum"] / total * 100).round(1)
print(f"\nAndel av total importance:")
print(summary[["sum", "andel_%"]])
# Out:
# ==================================================
# SUMMERAT PER KATEGORI
# ==================================================
#                       sum       mean  count
# kategori_grov
# Numerisk       288.278799   9.008712     32
# Text           111.425452   0.222851    500
# Kategorisk      49.180380  12.295095      4
#
# Andel av total importance:
#                       sum  andel_%
# kategori_grov
# Numerisk       288.278799     64.2
# Text           111.425452     24.8
# Kategorisk      49.180380     11.0

# %% [markdown]
# > **Observation:** I den fulla modellen står de numeriska featurena för ~72 % av den totala importance, kategoriska ~11 % och text bara ~16 % — trots att texten ensam (Pipeline 1) nådde R² 0.45! Förklaringen är **informations-redundans**: texten beskriver samma saker som siffrorna (storlek, läge, standard), bara med ord. När modellen har exakta siffror tillgängliga föredrar den dem, och texten blir en reservkälla. Detta visar att feature importance alltid måste tolkas i kontext av vilka andra features som finns med.

# %% [markdown]
# ### 3.2 Grid Search för Pipeline 2
#
# Samma optimeringsstrategi som för Pipeline 1, nu på den fulla modellen. Eftersom den uttömmande sökrymden hade krävt tusentals kombinationer använder vi en reducerad sökrymd med de mest lovande värdena.

# %%
# Kan vi ytterligare förbättra resultatet med Grid Search?

# ============================================================
# KERAS TUNER GRID SEARCH — Pipeline 2
# Hittar bästa hyperparametrarna för vår modell
# ============================================================

import keras_tuner as kt
import tensorflow as tf
import numpy as np
from sklearn.metrics import r2_score

# ============================================================
# STEG 1: Definiera build_model med hyperparametrar
# 64 kombinationer, vill inte köra mer just nu för det tar så lång tid.
# ============================================================
def build_model(hp):
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(X_train_full.shape[1],)),
        
        # Första dolda lagret
        tf.keras.layers.Dense(
            units=hp.Choice("n_neurons_layer1", [128, 256]),
            activation="relu"
        ),
        tf.keras.layers.Dropout(
            hp.Choice("dropout_rate_layer1", [0.3, 0.4])
        ),
        
        # Andra dolda lagret
        tf.keras.layers.Dense(
            units=hp.Choice("n_neurons_layer2", [64, 128]),
            activation="relu"
        ),
        tf.keras.layers.Dropout(
            hp.Choice("dropout_rate_layer2", [0.2, 0.3])
        ),
        
        # Tredje dolda lagret (mindre)
        tf.keras.layers.Dense(
            units=hp.Choice("n_neurons_layer3", [32, 64]),
            activation="relu"
        ),
        
        # Output: 1 neuron, linjär (regression)
        tf.keras.layers.Dense(1)
    ])
    
    # Optimerare med olika learning rates
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005])
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    
    model.compile(
        optimizer=optimizer,
        loss="mae",
        metrics=["mae"]
    )
    return model

# ============================================================
# STEG 2: Skapa GridSearch Tuner
# ============================================================
tuner = kt.GridSearch(
    hypermodel=build_model,
    objective="val_mae",            # vi minimerar val_mae för regression
    executions_per_trial=1,
    overwrite=True,
    directory="keras_tuner_airbnb",
    project_name="grid_search_pipeline2"
)

# Visa sökrymden
tuner.search_space_summary()

# ============================================================
# STEG 3: Kör grid search
# 64 kombinationer × upp till 100 epochs (med Early Stopping)
# ============================================================
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=5, restore_best_weights=True
)

print("\nStartar Grid Search... (tar några minuter)")
tuner.search(
    X_train_full, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)

# ============================================================
# STEG 4: Hämta bästa hyperparametrarna
# ============================================================
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print("\n" + "=" * 60)
print("BÄSTA HYPERPARAMETRAR FUNNA")
print("=" * 60)
print(f"  Neuroner lager 1:        {best_hps.get('n_neurons_layer1')}")
print(f"  Dropout lager 1:         {best_hps.get('dropout_rate_layer1')}")
print(f"  Neuroner lager 2:        {best_hps.get('n_neurons_layer2')}")
print(f"  Dropout lager 2:         {best_hps.get('dropout_rate_layer2')}")
print(f"  Neuroner lager 3:        {best_hps.get('n_neurons_layer3')}")
print(f"  Learning rate:           {best_hps.get('learning_rate')}")

# ============================================================
# STEG 5: Bygg den bästa modellen och träna ordentligt
# ============================================================
best_model = build_model(best_hps)

print(f"\nBästa modell — antal parametrar: {best_model.count_params():,}")

early_stop_final = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=15, restore_best_weights=True
)

print("\nTränar bästa modellen i upp till 100 epochs...")
history_best = best_model.fit(
    X_train_full, y_train,
    validation_data=(X_test_full, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop_final],
    verbose=1
)

# ============================================================
# STEG 6: Utvärdera bästa modellen med alla mätvärden
# ============================================================
y_pred_best = best_model.predict(X_test_full).flatten()

mae_best   = np.mean(np.abs(y_pred_best - y_test))
rmse_best  = np.sqrt(np.mean((y_pred_best - y_test) ** 2))
medae_best = np.median(np.abs(y_test - y_pred_best))
mape_best  = np.mean(np.abs((y_test - y_pred_best) / y_test)) * 100
r2_best    = r2_score(y_test, y_pred_best)

mean_pred = y_train.mean()
mae_base = np.mean(np.abs(y_test - mean_pred))

print("\n" + "=" * 60)
print("PIPELINE 2 — GRID SEARCH OPTIMERAD")
print("=" * 60)
print(f"Jämförelse:")
print(f"  MAE 'gissa medel':       {mae_base:.1f} SEK")
print(f"  MAE pipeline 1 (text):   441.7 SEK    R² 0.447")
print(f"  MAE pipeline 2 (allt):   361.7 SEK    R² 0.613")
print(f"  MAE Grid Search:         {mae_best:.1f} SEK    R² {r2_best:.3f}   ← ny")
print(f"")
print(f"Detaljerat:")
print(f"  MAE:       {mae_best:>7.1f} SEK")
print(f"  Median AE: {medae_best:>7.1f} SEK")
print(f"  RMSE:      {rmse_best:>7.1f} SEK")
print(f"  MAPE:      {mape_best:>7.1f} %")
print(f"  R²:        {r2_best:>7.3f}")
print(f"  Relativt fel: {mae_best/y_test.mean()*100:.1f}%")

# ============================================================
# STEG 7: Spara bästa modellen
# ============================================================
#best_model.save("best_airbnb_model.h5")
#print("\nBästa modellen sparad som best_airbnb_model.h5")

# ============================================================
# STEG 8: Plotta loss-kurvan
# ============================================================
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_best.history["loss"], label="Training loss")
plt.plot(history_best.history["val_loss"], label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("MAE (SEK)")
plt.title("Bästa modellen: Loss över epochs")
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_best, alpha=0.4, s=10)
mx = max(y_test.max(), y_pred_best.max())
plt.plot([0, mx], [0, mx], "r--", linewidth=1)
plt.xlabel("Faktiskt pris (SEK)")
plt.ylabel("Förutsagt pris (SEK)")
plt.title(f"Predictions vs sanning — MAE {mae_best:.0f} SEK")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Trial 64 Complete [00h 00m 18s]
# val_mae: 343.8669738769531
#
# Best val_mae So Far: 337.557373046875
# Total elapsed time: 00h 14m 09s
#
# ============================================================
# BÄSTA HYPERPARAMETRAR FUNNA
# ============================================================
#   Neuroner lager 1:        256
#   Dropout lager 1:         0.3
#   Neuroner lager 2:        64
#   Dropout lager 2:         0.3
#   Neuroner lager 3:        32
#   Learning rate:           0.001
#
# Bästa modell — antal parametrar: 156,033
#
# Tränar bästa modellen i upp till 100 epochs...
# Epoch 1/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1110.0707 - mae: 1110.0707 - val_loss: 696.7503 - val_mae: 696.7503
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 604.3195 - mae: 604.3195 - val_loss: 498.1209 - val_mae: 498.1209
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 442.0964 - mae: 442.0964 - val_loss: 421.6608 - val_mae: 421.6608
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 404.6134 - mae: 404.6134 - val_loss: 402.0676 - val_mae: 402.0676
# Epoch 5/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 382.2740 - mae: 382.2740 - val_loss: 386.6525 - val_mae: 386.6525
# Epoch 6/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 374.9832 - mae: 374.9832 - val_loss: 381.1110 - val_mae: 381.1110
# Epoch 7/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 360.6252 - mae: 360.6252 - val_loss: 378.7366 - val_mae: 378.7366
# Epoch 8/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 354.2526 - mae: 354.2526 - val_loss: 375.8854 - val_mae: 375.8854
# Epoch 9/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 348.7033 - mae: 348.7033 - val_loss: 374.1326 - val_mae: 374.1326
# Epoch 10/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 344.5192 - mae: 344.5192 - val_loss: 368.8267 - val_mae: 368.8267
# Epoch 11/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 342.4307 - mae: 342.4307 - val_loss: 367.3771 - val_mae: 367.3771
# Epoch 12/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 333.9326 - mae: 333.9326 - val_loss: 362.7392 - val_mae: 362.7392
# Epoch 13/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 330.3444 - mae: 330.3444 - val_loss: 365.0654 - val_mae: 365.0654
# Epoch 14/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 332.3530 - mae: 332.3530 - val_loss: 362.8448 - val_mae: 362.8448
# Epoch 15/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 326.5781 - mae: 326.5781 - val_loss: 362.7278 - val_mae: 362.7278
# Epoch 16/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 324.6172 - mae: 324.6172 - val_loss: 359.1893 - val_mae: 359.1893
# Epoch 17/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 314.2319 - mae: 314.2319 - val_loss: 359.9031 - val_mae: 359.9031
# Epoch 18/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 311.9286 - mae: 311.9286 - val_loss: 359.6849 - val_mae: 359.6849
# Epoch 19/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 312.1820 - mae: 312.1820 - val_loss: 358.8562 - val_mae: 358.8562
# Epoch 20/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 302.9747 - mae: 302.9747 - val_loss: 360.2904 - val_mae: 360.2904
# Epoch 21/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 306.5982 - mae: 306.5982 - val_loss: 360.3159 - val_mae: 360.3159
# Epoch 22/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 305.0835 - mae: 305.0835 - val_loss: 363.8862 - val_mae: 363.8862
# Epoch 23/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 302.3310 - mae: 302.3310 - val_loss: 364.4634 - val_mae: 364.4634
# Epoch 24/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 299.4041 - mae: 299.4041 - val_loss: 364.3088 - val_mae: 364.3088
# Epoch 25/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 295.9338 - mae: 295.9338 - val_loss: 360.3537 - val_mae: 360.3537
# Epoch 26/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 290.9154 - mae: 290.9154 - val_loss: 366.6897 - val_mae: 366.6897
# Epoch 27/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 291.1544 - mae: 291.1544 - val_loss: 363.1936 - val_mae: 363.1936
# Epoch 28/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 287.9291 - mae: 287.9291 - val_loss: 357.1108 - val_mae: 357.1108
# Epoch 29/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 284.5617 - mae: 284.5617 - val_loss: 362.7393 - val_mae: 362.7393
# Epoch 30/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 285.1797 - mae: 285.1797 - val_loss: 360.0388 - val_mae: 360.0388
# Epoch 31/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 277.9048 - mae: 277.9048 - val_loss: 356.4928 - val_mae: 356.4928
# Epoch 32/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 278.4504 - mae: 278.4504 - val_loss: 373.6526 - val_mae: 373.6526
# Epoch 33/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 274.4371 - mae: 274.4371 - val_loss: 362.0739 - val_mae: 362.0739
# Epoch 34/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 270.8518 - mae: 270.8518 - val_loss: 361.2635 - val_mae: 361.2635
# Epoch 35/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 270.2424 - mae: 270.2424 - val_loss: 359.7742 - val_mae: 359.7742
# Epoch 36/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 262.6853 - mae: 262.6853 - val_loss: 357.0557 - val_mae: 357.0557
# Epoch 37/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 272.5465 - mae: 272.5465 - val_loss: 360.4787 - val_mae: 360.4787
# Epoch 38/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 262.4207 - mae: 262.4207 - val_loss: 357.4073 - val_mae: 357.4073
# Epoch 39/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 258.4697 - mae: 258.4697 - val_loss: 360.4015 - val_mae: 360.4015
# Epoch 40/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 262.0653 - mae: 262.0653 - val_loss: 360.4163 - val_mae: 360.4163
# Epoch 41/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 258.2558 - mae: 258.2558 - val_loss: 360.5743 - val_mae: 360.5743
# Epoch 42/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 249.7258 - mae: 249.7258 - val_loss: 368.0898 - val_mae: 368.0898
# Epoch 43/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 253.3743 - mae: 253.3743 - val_loss: 365.5020 - val_mae: 365.5020
# Epoch 44/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 252.3094 - mae: 252.3094 - val_loss: 362.3248 - val_mae: 362.3248
# Epoch 45/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 248.5415 - mae: 248.5415 - val_loss: 360.1180 - val_mae: 360.1180
# Epoch 46/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 247.5487 - mae: 247.5487 - val_loss: 357.1079 - val_mae: 357.1079
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# ============================================================
# PIPELINE 2 — GRID SEARCH OPTIMERAD
# ============================================================
# Jämförelse:
#   MAE 'gissa medel':       663.9 SEK
#   MAE pipeline 1 (text):   441.7 SEK    R² 0.447
#   MAE pipeline 2 (allt):   361.7 SEK    R² 0.613
#   MAE Grid Search:         356.5 SEK    R² 0.613   ← ny
#
# Detaljerat:
#   MAE:         356.5 SEK
#   Median AE:   231.4 SEK
#   RMSE:        515.9 SEK
#   MAPE:         27.1 %
#   R²:          0.613
#   Relativt fel: 26.1%

# %%
# Grid search gav i princip ingen förbättring för pipe 2 heller. Det är tydligt att vår ursprungliga arkitektur var nära optimum.

# %% [markdown]
# ## 4. Prisestimator — använd modellen
#
# Här gör vi modellen praktiskt användbar: mata in en bostads egenskaper och få ett prisestimat tillbaka. Vi bygger två varianter:
#
# 1. **Full variant** — alla features, mer att fylla i men säkrare prediktion.
# 2. **Text-variant** — bara de fem fritextfälten, behändigare att testa.
#
# > **Obs:** modellen är tränad på Stockholm. Ger man den t.ex. koordinater utanför staden, eller kategorivärden den aldrig sett, blir estimatet missvisande. Modellen är också medvetet konservativ mot extremt dyra listings eftersom vi strök de översta 5 % vid träningen.

# %%
# PRISESTIMATOR! Mata in värden och få en prediktion!

# Först en med alla variabler, omständigare att fylla i, men säkrare prediktion.
# Efteråt kommer en variant med bara fritext-variablerna som är behändigare att populera.

# %%
# ============================================================
# PRISESTIMATOR
# Mata in en bostads-beskrivning → få pris
# ============================================================

def estimate_price(listing_dict, model=best_model):
    """
    Estimera pris för en AirBnB-listing.
    
    listing_dict: dict med textfält, kategoriska fält, och numeriska fält
    """
    import pandas as pd
    from scipy.sparse import hstack, csr_matrix
    
    # Steg 1: Gör om input till en DataFrame med 1 rad
    sample_df = pd.DataFrame([listing_dict])
    
    # Steg 2: TF-IDF på textfält (transform, inte fit!)
    text_vecs = []
    for col in tfidf_settings.keys():
        text = sample_df.get(col, pd.Series(["okänt"])).fillna("okänt").astype(str)
        text_vec = tfidf_vectorizers[col].transform(text)
        text_vecs.append(text_vec)
    
    # Steg 3: Kategoriska — använd samma encoder som tidigare
    cat_values = []
    for col in cat_cols:
        val = sample_df.get(col, pd.Series(["okänt"])).iloc[0]
        # Om värdet inte finns i encoder: fall tillbaka på 'okänt' eller 0
        if val in encoders[col].classes_:
            enc = encoders[col].transform([val])[0]
        else:
            enc = 0  # default
        cat_values.append(enc)
    
    # Steg 4: Numeriska — fyll saknade med median från träning
    num_values = []
    for col in num_cols:
        if col in sample_df.columns and pd.notna(sample_df[col].iloc[0]):
            num_values.append(float(sample_df[col].iloc[0]))
        else:
            num_values.append(df[col].median())  # default = träningsmedian
    
    # Steg 5: Skala numeriska med samma scaler
    import numpy as np
    num_array = np.array(num_values).reshape(1, -1)
    num_scaled = scaler.transform(num_array).astype("float32")
    
    # Steg 6: Kombinera till en feature-vektor
    num_sp = csr_matrix(num_scaled)
    cat_sp = csr_matrix(np.array(cat_values).reshape(1, -1).astype("float32"))
    
    X_sample = hstack([num_sp, cat_sp] + text_vecs).toarray().astype("float32")
    
    # Steg 7: Förutsäg
    predicted_price = model.predict(X_sample, verbose=0).flatten()[0]
    
    return predicted_price


# ============================================================
# EXEMPEL 1: En enkel lägenhet på Södermalm
# ============================================================
listing_1 = {
    "name":                  "Cozy studio in Södermalm",
    "description":           "Charming small apartment, 5 minutes walk to subway. Perfect for solo travelers or couples.",
    "amenities":             "wifi, kitchen, washer, heating",
    "neighborhood_overview": "Södermalm is a trendy area with great restaurants and shops.",
    "host_about":            "I love hosting travelers from around the world!",
    
    "property_type":         "Entire rental unit",
    "room_type":             "Entire home/apt",
    "neighbourhood_cleansed": "Södermalms",
    "host_response_time":    "within an hour",
    
    "bedrooms":              1,
    "bathrooms":             1,
    "beds":                  1,
    "accommodates":          2,
    "minimum_nights":        2,
    "maximum_nights":        90,
    "number_of_reviews":     45,
    "number_of_reviews_ltm": 15,
    "reviews_per_month":     2.5,
    "review_scores_rating":  4.8,
    "latitude":              59.3151,
    "longitude":             18.0758,
    "availability_30":       15,
}

price_1 = estimate_price(listing_1)
print(f"Exempel 1 (studio Södermalm):  {price_1:.0f} SEK/natt")


# ============================================================
# EXEMPEL 2: En större lägenhet i Östermalm
# ============================================================
listing_2 = {
    "name":                  "Luxury 3-bedroom apartment in Östermalm",
    "description":           "Spacious renovated apartment with high ceilings and balcony. Family-friendly. 2 minutes to subway.",
    "amenities":             "wifi, kitchen, washer, dryer, dishwasher, elevator, tv, parking",
    "neighborhood_overview": "Östermalm is one of Stockholm's most exclusive neighborhoods.",
    "host_about":            "Welcome! I host with care and attention to detail.",
    
    "property_type":         "Entire rental unit",
    "room_type":             "Entire home/apt",
    "neighbourhood_cleansed": "Östermalms",
    "host_response_time":    "within an hour",
    
    "bedrooms":              3,
    "bathrooms":             2,
    "beds":                  4,
    "accommodates":          6,
    "minimum_nights":        3,
    "maximum_nights":        180,
    "number_of_reviews":     80,
    "number_of_reviews_ltm": 25,
    "reviews_per_month":     3.5,
    "review_scores_rating":  4.9,
    "latitude":              59.3367,
    "longitude":             18.0857,
    "availability_30":       8,
}

price_2 = estimate_price(listing_2)
print(f"Exempel 2 (lyxlägenhet Östermalm): {price_2:.0f} SEK/natt")


# ============================================================
# EXEMPEL 3: Ett privat rum i ytterstaden
# ============================================================
listing_3 = {
    "name":                  "Private room near subway",
    "description":           "Simple room in shared apartment. Good for budget travelers.",
    "amenities":             "wifi, shared kitchen, lockbox",
    "neighborhood_overview": "okänt",
    "host_about":            "okänt",
    
    "property_type":         "Private room in rental unit",
    "room_type":             "Private room",
    "neighbourhood_cleansed": "Vällingby",
    "host_response_time":    "within a few hours",
    
    "bedrooms":              1,
    "bathrooms":             1,
    "beds":                  1,
    "accommodates":          1,
    "minimum_nights":        1,
    "maximum_nights":        30,
    "number_of_reviews":     10,
    "number_of_reviews_ltm": 3,
    "reviews_per_month":     0.8,
    "review_scores_rating":  4.5,
    "latitude":              59.3650,
    "longitude":             17.8730,
    "availability_30":       25,
}

price_3 = estimate_price(listing_3)
print(f"Exempel 3 (privat rum Vällingby): {price_3:.0f} SEK/natt")


# ============================================================
# Exemplet från cellen nedanför med adderade numeriska variabler
# ============================================================
listing_4 = {
    "name": "Elegant & light 3 room apartment in SoFo, 97sqm",
    "description": "The apartment is on the 2nd floor in a beautiful building from 1880 situated in the heart of the trendy area called SoFo at Södermalm. It is a large, light, airy and very stylish 3 room apartment with all the rooms facing a wonderful park giving you a nice view to look at and great privacy. The apartment can easily and very comfortably host 4 guests. The area is one of the popular places in Stockholm with a great variaty of restaurants, bars, cafees and shops.The apartment is newly renovated and is painted in white and light yellow and is furnished in a modern style. The celings are high and windows large and one of the bedrooms have a double bed and the other bedroom has two single beds that could easily be made into one double bed. You have a nice living room with a lot of space and a smart TV with Internet/Netflix and Cable TV. You have access to the whole apartment. The apartment is on 2nd floor and the building has no elevator. If you would like to book the garage parking (only one) you need to eserv it when you make the booking. If it is available there is an extra cost of 200kr per night.",
    "amenities":   "Hair dryer, Shampoo, Hot water, Bedroom and laundry, Washer – In building, Dryer – In building, Towels, bed sheets, soap, and toilet paper, Hangers, Bed linens, Extra pillows and blankets, Room-darkening shades, Iron, Entertainment, Ethernet connection, TV with standard cable, Family, Crib, Pack n play/Travel crib, Baby monitor, Window guards, Babysitter recommendations, Heating and cooling, Indoor fireplace, Heating",
    "neighborhood_overview": "Hornsgatan Hotel is located next to Mariatorget in Södermalm.. The area is well-known for its restaurants, cafes and shops. Walking distance to the Old Town.",
    "host_about":  "We are a family company offering a number of personally designed apartments to people visiting Stockholm for shorter och longer periods. We will do our out most to meet your expectations and give you a memorable stay in the houses and area where our family have lived and worked for almost 150 years.",
    
    "property_type":         "Entire rental unit",
    "room_type":             "Entire home/apt",
    "neighbourhood_cleansed": "Södermalms",
    "host_response_time":    "within an hour",


    
    "bedrooms":              2,
    "bathrooms":             1,
    "beds":                  4,
    "accommodates":          4,
    "minimum_nights":        1,
    "maximum_nights":        30,
    "number_of_reviews":     329,
    "number_of_reviews_ltm": 3,
    "reviews_per_month":     0.8,
    "review_scores_rating":  4.82,
    "latitude":              59.3299,
    "longitude":             18.0430,
    "availability_30":       25,
}

price_4 = estimate_price(listing_4)
print(f"Exempel 4 (Elegant & light 3 room apartment in SoFo, 97sqm): {price_4:.0f} SEK/natt")

# ============================================================
# Exempel2 från cellen nedanför med adderade numeriska variabler. Verkligt pris 377 SEK
# ============================================================
listing_5 = {
    "name": "Room in Sollentuna, Sweden",
    "description": "18 mins on direct train to/from Arlanda airport & 14 mins direct (same train) into central Stockholm. 5 mins walk from train station/ Sollentunas mall. Large room with desk. There is kitchen access but this is limited due to my wife's home baking business, guests may cook more simple foods (e.g. boiling water for pasta, warming something in the microwave). We are a friendly/lively family with a young son. I am English and my wife is Bolivian. Swedish, english and spanish are spoken at home",
    "amenities":   "Lock on bedroom door, Kitchen, Wifi, Washer, Dryer, Hair dryer, Refrigerator",
    "neighborhood_overview": "Sollentuna is a really nice part of Stockholm. Lots of big villas, nice walks down by the lake, where there si also a beach and bbq area. The mall in Sollentuna (5 mins away) is big and well presented. Plenty of Restaurants/cafes around the centre - like O'learys and Texas Longhorn. Our favourites are Garden (in the mall) the chinese just outside the mall and the Columbian restaurant 2 mins from where we live. There is a LIDL (cheap supermarket) 2 minutes walk away and we are only a couple of stops away on the train line from Friends Arena (for concerts and football) and Mall of Scandinavia for shopping",
    "host_about":  "okänt",
    
    "property_type":         "Room in a rental unit",
    "room_type":             "Private room",
    "neighbourhood_cleansed": "Sollentuna",
    "host_response_time":    "within a few hours",


    
    "bedrooms":              1,
    "bathrooms":             0,
    "beds":                  1,
    "accommodates":          2,
    "minimum_nights":        1,
    "maximum_nights":        30,
    "number_of_reviews":     143,
    "number_of_reviews_ltm": 3,
    "reviews_per_month":     0.8,
    "review_scores_rating":  4.86,
    "latitude":              59.4283,
    "longitude":             17.9380,
    "availability_30":       25,
}

price_5 = estimate_price(listing_5)
print(f"Exempel 5 (Room in Sollentuna, Sweden): {price_5:.0f} SEK/natt")
# Out:
# C:\Users\ES7233\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\ES7233\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\ES7233\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Exempel 1 (studio Södermalm):  966 SEK/natt
# Exempel 2 (lyxlägenhet Östermalm): 1490 SEK/natt
# Exempel 3 (privat rum Vällingby): 148 SEK/natt
# Exempel 4 (Elegant & light 3 room apartment in SoFo, 97sqm): 1654 SEK/natt
# Exempel 5 (Room in Sollentuna, Sweden): 388 SEK/natt
# C:\Users\ES7233\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\ES7233\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Version 2, endast textvariabler. Enklare att fylla i manuellt men tappar en del prestanda såklart. Använder pipeline 1

# ============================================================
# PRISESTIMATOR — endast textfält
# Mata in 5 textfält → få ett prisestimat
# ============================================================

def estimate_price_text(listing_dict, model=model_text):
    """
    Estimera pris baserat på endast textfält.
    
    listing_dict kan innehålla:
        name, description, amenities, 
        neighborhood_overview, host_about
    
    Saknade fält fylls automatiskt med "okänt".
    """
    import pandas as pd
    from scipy.sparse import hstack
    
    # Steg 1: Bygg en rad med alla textfält
    sample = {}
    for col in tfidf_settings.keys():
        sample[col] = listing_dict.get(col, "okänt") or "okänt"
    sample_df = pd.DataFrame([sample])
    
    # Steg 2: TF-IDF på varje fält
    text_vecs = []
    for col in tfidf_settings.keys():
        vec = tfidf_vectorizers[col].transform(sample_df[col].astype(str))
        text_vecs.append(vec)
    
    # Steg 3: Kombinera
    X_sample = hstack(text_vecs).toarray().astype("float32")
    
    # Steg 4: Förutsäg
    return model.predict(X_sample, verbose=0).flatten()[0]


# ============================================================
# EXEMPEL — leka med olika beskrivningar
# ============================================================

# Exempel 1: Minimal info
listing_a = {
    "name": "Apartment",
}
price_a = estimate_price_text(listing_a)
print(f"Bara namn ('Apartment'):  {price_a:.0f} SEK/natt")


# Exempel 2: Budget-rum
listing_b = {
    "name":        "Private room near subway",
    "description": "Simple room, good for budget travelers. Self check-in with lockbox.",
    "amenities":   "wifi, shared kitchen, lockbox",
}
price_b = estimate_price_text(listing_b)
print(f"Budget privat rum:         {price_b:.0f} SEK/natt")


# Exempel 3: Familjelägenhet
listing_c = {
    "name":        "Spacious family apartment in Södermalm",
    "description": "Beautiful 3-bedroom apartment, perfect for families. 5 minutes to subway. Recently renovated.",
    "amenities":   "wifi, kitchen, washer, dryer, tv, elevator, dishwasher",
    "neighborhood_overview": "Södermalm is a great area for families with parks and good restaurants.",
    "host_about":  "We are a Swedish family who love welcoming guests to our beautiful city.",
}
price_c = estimate_price_text(listing_c)
print(f"Familjelägenhet Södermalm: {price_c:.0f} SEK/natt")


# Exempel 4: Lyxlägenhet
listing_d = {
    "name":        "Luxury 4-bedroom penthouse Östermalm",
    "description": "Stunning penthouse with balcony and city view. Premium location 2 minutes to subway. Family-friendly with all modern amenities.",
    "amenities":   "wifi, kitchen, washer, dryer, tv, elevator, dishwasher, parking, balcony",
    "neighborhood_overview": "Östermalm is Stockholm's most exclusive neighborhood with high-end shopping and dining.",
    "host_about":  "I am a passionate host with years of experience welcoming international travelers.",
}
price_d = estimate_price_text(listing_d)
print(f"Lyx penthouse Östermalm:   {price_d:.0f} SEK/natt")


# Exempel 5: Custom - https://www.airbnb.com/rooms/40459780?adults=1&check_in=2026-06-27&search_mode=regular_search&source_impression_id=p3_1779776622_P3O76-HBEEiIdlwJ&previous_page_section_name=1000&federated_search_id=89ba3525-7d93-4765-8b00-d71f57774e61&guests=1&check_out=2026-06-28
listing_d = {
    "name": "Cosy single room with private bathroom",
    "description": "We offer a peaceful accommodation with a family atmosphere and personal attention. The staff at the hotel have great knowledge of Stockholm and will gladly give you tips on restaurants, museums and attractions. Hotel Hornsgatan is located on the first floor of a residential building from 1905. Our 22 rooms are individually decorated with views towards Hornsgatan, quiet courtyard or back alley. Of our 22 rooms, nine rooms have private bathrooms, the remaining 13 rooms share five bathrooms located in the corridor. All bathrooms have a shower, sink and toilet. The price of a room includes a breakfast buffet. We offer several kinds of yogurt and cereal, assorted breads with toppings, eggs, fruit and juice, coffee and tea. We have options to suit vegetarians, vegans, gluten and lactose intolerant. Let us know in advance if you require a special diet. Our breakfast room located on the first floor is available 24/7. Here you can help yourself to free coffee, tea, juice, fruit and biscuits any time. For the rooms located on the ground floor, across the court yard there is a fully equipped kitchen availble. This kitchen area is shared between five rooms and equipped with fridge, freezer, stove and owen. We offer a peaceful accommodation with a family atmosphere and personal attention. We at the hotel have great knowledge of Stockholm and will gladly give you tips on restaurants, museums and attractions. Hotel Hornsgatan is located on the first floor of a residential building from 1905. Our 17 rooms are individually decorated with views towards Hornsgatan, quiet courtyard or back street. Of our 17 rooms, four rooms have private bathrooms, the remaining 13 rooms share five bathrooms located in the corridor. In all bathrooms there is a shower, sink and toilet. Located on the ground floor, across the court yard we have five budget rooms that all have a smaller private bathroom.",
    "amenities":   "Hair dryer, Shampoo, Bedroom and laundry, Hangers, Iron, Entertainment, TV, Family Crib, Heating and cooling, Heating, Home safety, Exterior security, cameras on property CCTV camera placed in the reception, Smoke alarm, Wifi, Dedicated workspace, Kitchen and dining, Dishes and silverware, Bowls, chopsticks, plates, cups, Breakfast",
    "neighborhood_overview": "Hornsgatan Hotel is located next to Mariatorget in Södermalm.. The area is well-known for its restaurants, cafes and shops. Walking distance to the Old Town.",
    "host_about":  "okänt",
}
price_d = estimate_price_text(listing_d)
print(f"Eget exempel 1:   {price_d:.0f} SEK/natt")


# Exempel 6: Custom - https://www.airbnb.com/rooms/36925986?adults=1&check_in=2026-06-16&check_out=2026-06-17&search_mode=regular_search&source_impression_id=p3_1779776622_P3FT3jaL1NuAk32B&previous_page_section_name=1000&federated_search_id=89ba3525-7d93-4765-8b00-d71f57774e61
listing_d = {
    "name": "Elegant & light 3 room apartment in SoFo, 97sqm",
    "description": "The apartment is on the 2nd floor in a beautiful building from 1880 situated in the heart of the trendy area called SoFo at Södermalm. It is a large, light, airy and very stylish 3 room apartment with all the rooms facing a wonderful park giving you a nice view to look at and great privacy. The apartment can easily and very comfortably host 4 guests. The area is one of the popular places in Stockholm with a great variaty of restaurants, bars, cafees and shops.The apartment is newly renovated and is painted in white and light yellow and is furnished in a modern style. The celings are high and windows large and one of the bedrooms have a double bed and the other bedroom has two single beds that could easily be made into one double bed. You have a nice living room with a lot of space and a smart TV with Internet/Netflix and Cable TV. You have access to the whole apartment. The apartment is on 2nd floor and the building has no elevator. If you would like to book the garage parking (only one) you need to eserv it when you make the booking. If it is available there is an extra cost of 200kr per night.",
    "amenities":   "Hair dryer, Shampoo, Hot water, Bedroom and laundry, Washer – In building, Dryer – In building, Towels, bed sheets, soap, and toilet paper, Hangers, Bed linens, Extra pillows and blankets, Room-darkening shades, Iron, Entertainment, Ethernet connection, TV with standard cable, Family, Crib, Pack n play/Travel crib, Baby monitor, Window guards, Babysitter recommendations, Heating and cooling, Indoor fireplace, Heating",
    "neighborhood_overview": "Hornsgatan Hotel is located next to Mariatorget in Södermalm.. The area is well-known for its restaurants, cafes and shops. Walking distance to the Old Town.",
    "host_about":  "We are a family company offering a number of personally designed apartments to people visiting Stockholm for shorter och longer periods. We will do our out most to meet your expectations and give you a memorable stay in the houses and area where our family have lived and worked for almost 150 years.",
}
price_d = estimate_price_text(listing_d)
print(f"Eget exempel 2:   {price_d:.0f} SEK/natt")
# Osäker prediktion på denna, jag går upp till cellen ovanvför och provar addera de numeriska variablerna



# Exempel 7: Custom - https://www.airbnb.com/rooms/37319611?adults=1&check_in=2026-06-16&check_out=2026-06-17&search_mode=regular_search&category_tag=Tag%3A8678&photo_id=822647784&source_impression_id=p3_1779776622_P34zkkc4JUkaMTlB&previous_page_section_name=1000&federated_search_id=89ba3525-7d93-4765-8b00-d71f57774e61
# Verkligt pris 377 SEK
listing_d = {
    "name": "Room in Sollentuna, Sweden",
    "description": "18 mins on direct train to/from Arlanda airport & 14 mins direct (same train) into central Stockholm. 5 mins walk from train station/ Sollentunas mall. Large room with desk. There is kitchen access but this is limited due to my wife's home baking business, guests may cook more simple foods (e.g. boiling water for pasta, warming something in the microwave). We are a friendly/lively family with a young son. I am English and my wife is Bolivian. Swedish, english and spanish are spoken at home",
    "amenities":   "Lock on bedroom door, Kitchen, Wifi, Washer, Dryer, Hair dryer, Refrigerator",
    "neighborhood_overview": "Sollentuna is a really nice part of Stockholm. Lots of big villas, nice walks down by the lake, where there si also a beach and bbq area. The mall in Sollentuna (5 mins away) is big and well presented. Plenty of Restaurants/cafes around the centre - like O'learys and Texas Longhorn. Our favourites are Garden (in the mall) the chinese just outside the mall and the Columbian restaurant 2 mins from where we live. There is a LIDL (cheap supermarket) 2 minutes walk away and we are only a couple of stops away on the train line from Friends Arena (for concerts and football) and Mall of Scandinavia for shopping",
    "host_about":  "okänt",
}
price_d = estimate_price_text(listing_d)
print(f"Eget exempel 3:   {price_d:.0f} SEK/natt")
# Går upp och lägger till övriga variabler för att se om prediktionen blir säkrare

# Exempel 8: https://www.airbnb.com/rooms/1639865996303724700?adults=2&check_in=2026-06-19&check_out=2026-06-20&location=s%C3%B6dermalm&search_mode=regular_search&source_impression_id=p3_1779885228_P3v3d2kRaa4JhLnN&previous_page_section_name=1001&federated_search_id=f62754a9-c11d-423c-808a-2e29fae2ead0
# Verkligt pris 1953 SEK
listing_d = {
 "name": "Modern and Cosy Studio for 4, Stockholm Södermalm",
    "description": "Spacious Studio with smart design in Prime Location 23m2 Average size 140 x 200 cm bed140 x 200 cm Sofa Bed",
    "amenities":   "Hair dryer, Shampoo ,Conditioner ,Body soap ,Hot water ,Shower gel ,Bedroom and laundry ,Free washer – In building ,Hangers ,Bed linens ,Iron ,Entertainment ,TV ,Family ,Crib ,Heating and cooling ,Heating ,Home safety ,First aid kit ,Internet and office ,Wifi ,Kitchen and dining ,Microwave ,Mini fridge ,Hot water kettle ,Coffee maker ,Dining table ,Coffee ,Parking and facilities ,Elevator ,The home or building has an elevator that’s at least 52 inches deep and a doorway at least 32 inches wide ,Shared gym nearby ,Services ,Pets allowed ,Assistance animals are always allowed ,Luggage dropoff allowed ,For guests convenience when they have early arrival or late departure ,Self check-in ,Smart lock",
    "neighborhood_overview": "okänt",
    "host_about":  "After travelling around the world from Chicago to Kathmandu and everywhere in between, I created apartments that combine the best of boutique hotels and authentic homes. When you stay with me, you always get: an awesome location in a handpicked neighbourhood, interiors created by local designers, and a commitment to sustainability. My team of professional hospitality superheroes is here for you day and night to make sure you have a 5-star stay.",
}
price_d = estimate_price_text(listing_d)
print(f"Eget exempel 4:   {price_d:.0f} SEK/natt")
# Out:
# Bara namn ('Apartment'):  759 SEK/natt
# Budget privat rum:         123 SEK/natt
# Familjelägenhet Södermalm: 2414 SEK/natt
# Lyx penthouse Östermalm:   1792 SEK/natt
# Eget exempel 1:   1624 SEK/natt
# Eget exempel 2:   1286 SEK/natt
# Eget exempel 3:   274 SEK/natt
# Eget exempel 4:   1047 SEK/natt

# %% [markdown]
# ## 5. Affärsvärde
#
# Varför är den här modellen värdefull för ett företag som Airbnb?

# %%
"""
Affärsvärde:

Pris-rekommendation till nya värdar — "din lägenhet borde kosta ~1200 SEK"
Upptäcka under- och överprissatta listings — flagga listings där pris ≠ modellens estimat
Hjälp värdar optimera sina beskrivningar — "lägg till ordet 'family' om det stämmer, det är värt +525 SEK"
Konkurrentanalys — vad borde mitt rum kosta jämfört med liknande?

"""
# Out:
# '\nAffärsvärde:\n\nPris-rekommendation till nya värdar — "din lägenhet borde kosta ~1200 SEK"\nUpptäcka under- och överprissatta listings — flagga listings där pris ≠ modellens estimat\nHjälp värdar optimera sina beskrivningar — "lägg till ordet \'family\' om det stämmer, det är värt +525 SEK"\nKonkurrentanalys — vad borde mitt rum kosta jämfört med liknande?\n\n'

# %% [markdown]
# ## 6. Geografisk felanalys med interaktiv karta
#
# Var lyckas och misslyckas modellen rent geografiskt? Med en Folium-karta färgkodar vi varje testlisting efter prediktionsfel: grönt = litet fel, orange = medel, rött = stort fel. Om de röda punkterna klustrar i innerstaden bekräftar det att modellen har svårast med dyra, centrala premium-listings — samma mönster vi sett i enskilda exempel.

# %%
# Fräsig interaktiv karta med Folium där vi verkligen kan se hur vi har presterat

import folium
import numpy as np

# ============================================================
# Förbered data — använd X_test_df (DataFrame med alla kolumner)
# ============================================================
map_df = X_test_df.copy()

map_df["actual_price"]    = y_test
map_df["predicted_price"] = y_pred_best          # från Grid Search-modellen
map_df["abs_error"]       = np.abs(map_df["predicted_price"] - map_df["actual_price"])

# ============================================================
# Färgkodning efter felstorlek
# ============================================================

def error_color(abs_error):
    if abs_error < 250:
        return "green"      # bra prediktion
    elif abs_error < 750:
        return "orange"     # okej prediktion
    else:
        return "red"        # dålig prediktion


"""
# För procentuellt fel
def error_color_pct(actual_price, predicted_price):
    pct_error = abs(predicted_price - actual_price) / actual_price * 100
    if pct_error < 15:
        return "green"      # bra prediktion (< 15% fel)
    elif pct_error < 35:
        return "orange"     # okej prediktion (15-35%)
    else:
        return "red"        # dålig prediktion (> 35%)
"""

# ============================================================
# Bygg kartan
# ============================================================
m_error = folium.Map(
    location=[59.33, 18.06],   # Stockholm centrum
    zoom_start=11,
    tiles="CartoDB positron"   # ren, ljus bakgrund
)

for _, row in map_df.iterrows():
    color = error_color(row["abs_error"])
    folium.CircleMarker(
        location=[row["latitude"], row["longitude"]],
        radius=6,
        color=color,
        fill=True,
        fill_opacity=0.75,
        popup=folium.Popup(
            html=(
                f"<b>Namn:</b> {row['name']}<br>"
                f"<b>Faktiskt pris:</b> {row['actual_price']:.0f} kr<br>"
                f"<b>Förutsagt pris:</b> {row['predicted_price']:.0f} kr<br>"
                f"<b>Absolut fel:</b> {row['abs_error']:.0f} kr<br>"
                f"<b>Bostadstyp:</b> {row['property_type']}<br>"
                f"<b>Rumstyp:</b> {row['room_type']}<br>"
                f"<b>URL:</b> <a href={row['listing_url']} target=_blank>Länk</a>"
            ),
            max_width=300
        )
    ).add_to(m_error)

m_error
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_199b58d79268263c65b76f81fd85eb85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_199b58d79268263c65b76f81fd85eb85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_199b58d79268263c65b76f81fd85eb85 = L.map(
#                 &quot;map_199b58d79268263c65b76f81fd85eb85&quot;,
#                 {
#                     center: [59.33, 18.06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31f0aeb496dc94de0ccc55d50c358572 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31f0aeb496dc94de0ccc55d50c358572.addTo(map_199b58d79268263c65b76f81fd85eb85);
#
#
#             var circle_marker_56a03fe3619ee668508120217dc98fe6 = L.circleMarker(
#                 [59.3041747, 18.099544],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.75, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_199b58d79268263c65b76f81fd85eb85);
#
#
#         var popup_c1595d6055e540f73fef16f97ff502e7 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_3b162ddec035e9ada22a4d78ecbf5cbe = $(`&lt;div id=&quot;html_3b162ddec035e9ada22a4d78ecbf5cbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Namn:&lt;/b&gt; Familjeboende nära stan&lt;br&gt;&lt;b&gt;Faktiskt pris:&lt;/b&gt; 1100 kr&lt;br&gt;&lt;b&gt;Förutsagt pris:&lt;/b&gt; 1580 kr&lt;br&gt;&lt;b&gt;Absolut fel:&lt;/b&gt; 480 kr&lt;br&gt;&lt;b&gt;Bostadstyp:&lt;/b&gt; Entire rental unit&lt;br&gt;&lt;b&gt;Rumstyp:&lt;/b&gt; Entire home/apt&lt;br&gt;&lt;b&gt;URL:&lt;/b&gt; &lt;a href=https://www.airbnb.com/rooms/823213827989738794 target=_blank&gt;Länk&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_c1595d6055e540f73fef16f97ff502e7.setContent(html_3b162ddec035e9ada22a4d78ecbf5cbe);
#
#
#
#         circle_marker_56a03fe3619ee668508120217dc98fe6.bindPopup(popup_c1595d6055e540f73fef16f97ff502e7)
#         ;
#
#
#
#
#             var circle_marker_814ff4d2501e72b217bbd6776156daba = L.circleMarker(
#                 [59.2955, 18.00668],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.75, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_199b58d79268263c65b76f81fd85eb85);
#
#
#         var popup_7351282f4c4440db7bb8e16875c7dd8c = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_0ec02489dd2a1428d4cb2c87f78eced0 = $(`&lt;div id=&quot;html_0ec02489dd2a1428d4cb2c87f78eced0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Namn:&lt;/b&gt; Studio/Office Near STHLM city center,WC(NO SH0WER)&lt;br&gt;&lt;b&gt;Faktiskt pris:&lt;/b&gt; 494 kr&lt;br&gt;&lt;b&gt;Förutsagt pris:&lt;/b&gt; 598 kr&lt;br&gt;&lt;b&gt;Absolut fel:&lt;/b&gt; 104 kr&lt;br&gt;&lt;b&gt;Bostadstyp:&lt;/b&gt; Entire rental unit&lt;br&gt;&lt;b&gt;Rumstyp:&lt;/b&gt; Entire home/apt&lt;br&gt;&lt;b&gt;URL:&lt;/b&gt; &lt;a href=https://www.airbnb.com/rooms/14772796 target=_blank&gt;Länk&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_7351282f4c4440db7bb8e16875c7dd8c.setContent(html_0ec02489dd2a1428d4cb2c87f78eced0);
#
#
#
#         circle_marker_814ff4d2501e72b217bbd6776156daba.bindPopup(popup_7351282f4c4440db7bb8e16875c7dd8c)
#         ;
#
#
#
#
#             var circle_marker_bc47619aa2dd81c8a31e8d9defb78f00 = L.circleMarker(
#                 [59.24326, 18.08989],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.75, &quot;fillRule&quot;: &quot;even

# %%
# Spara som html

m_error.save("airbnb_error_map.html")
print("Karta sparad som airbnb_error_map.html")
print("Öppna i webbläsare eller bädda in i presentationen")
# Out:
# Karta sparad som airbnb_error_map.html
# Öppna i webbläsare eller bädda in i presentationen

# %% [markdown]
# ## 7. Slutsats och resultat
#
# ### Resultatöversikt
#
# | Modell | MAE | R² | Relativt fel |
# |---|---|---|---|
# | Gissa medelvärdet (baseline) | ~664 SEK | 0.00 | ~49 % |
# | Pipeline 1 — bara text | ~442 SEK | 0.45 | ~33 % |
# | Pipeline 2 — allt | ~362 SEK | 0.61 | ~26 % |
# | Grid Search-optimerad | ~360 SEK | 0.60 | ~26 % |
#
# ### Viktigaste lärdomar
#
# **1. Texten ensam är förvånansvärt stark.** Med enbart hyresvärdarnas fritextbeskrivningar förklarar modellen 45 % av prisvariationen. Det visar att värdar omedvetet kodar mycket prisrelevant information i sina beskrivningar — storlek, läge och standard framgår av orden.
#
# **2. Strukturerad data lyfter modellen ytterligare.** Att lägga till numeriska och kategoriska features sänker felet från 442 till 362 SEK och höjer R² till 0.61. Men ökningen är mindre än man kanske tror, eftersom text och siffror till stor del beskriver samma saker (informationsredundans).
#
# **3. Modellen har nått datans tak.** Grid Search över många arkitekturer gav ingen meningsfull förbättring — skillnaderna låg inom statistiskt brus. Det betyder att vår ursprungliga arkitektur redan var nära optimal, och att ytterligare prestanda kräver **mer eller annan data** (bilder, säsongspriser, konkurrenters priser) snarare än fler lager.
#
# **4. Deep Learning är inte alltid bästa valet.** Med ~3 000 rader är datasetet litet för neurala nätverk. En enklare OLS-regression i ett tidigare projekt nådde R² ~0.56 — bara strax under vårt neurala nätverk. För strukturerad tabelldata av denna storlek är enklare modeller (t.ex. XGBoost) ofta likvärdiga eller bättre. Deep Learning lönar sig först vid större datamängder eller när text/bilder är kärnan i problemet.
#
# ### Affärsvärde i korthet
#
# Modellen kan ge nya värdar en **datadriven prisrekommendation**, flagga **under- eller överprissatta listings**, och visa vilka ord i en beskrivning som hänger ihop med högre pris. Den geografiska felkartan pekar dessutom ut var premium-värdar tar ut ett påslag som modellen inte fångar — i sig en affärsinsikt om var prissättningen är som mest 'mänsklig'.
#
# ### Möjliga förbättringar
#
# - Kombinera flera städer för ett större träningsdataset (>50 000 rader).
# - Lägga till bildanalys (foton påverkar bokningsbeslut starkt).
# - Inkludera säsongs- och efterfrågedata.
# - Jämföra formellt mot XGBoost som baseline för tabelldata.
